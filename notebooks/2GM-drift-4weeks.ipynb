# %%
import numpy as np
from opendrift.readers import reader_ROMS_native
from opendrift.models.oceandrift import OceanDrift

o = OceanDrift(loglevel=20)  # Set loglevel to 0 for debug information
# Out:
# 17:02:26 INFO    opendrift.models.basemodel:532: OpenDriftSimulation initialised (version 1.10.4)

# %%
TGM_native = reader_ROMS_native.Reader('/g/data/fu5/deg581/SA_model/ocean_his_garkgw_2018_full.nc')
o.add_reader(TGM_native)
# Out:
# 17:02:27 INFO    opendrift.readers.reader_ROMS_native:84: Opening dataset: /g/data/fu5/deg581/SA_model/ocean_his_garkgw_2018_full.nc
# 17:02:27 INFO    opendrift.readers.reader_ROMS_native:100: Opening file with Dataset
# 17:02:27 INFO    opendrift.readers.reader_ROMS_native:176: 'gls_cmu0'
# 17:02:27 INFO    opendrift.readers.reader_ROMS_native:177: Did not find complete set of GLS parameters
# 17:02:27 WARNING opendrift.readers.basereader.structured:44: No proj string or projection could be derived, using 'fakeproj'. This assumes that the variables are structured and gridded approximately equidistantly on the surface (i.e. in meters). This must be guaranteed by the user. You can get rid of this warning by supplying a valid projection to the reader.
# 17:02:27 INFO    opendrift.readers.basereader.structured:59: Making interpolator for lon,lat to x,y conversion...

# %%
from datetime import timedelta,datetime

seed_time = [TGM_native.start_time, TGM_native.start_time + timedelta(hours=24*7)]
seed_number=24*7*3*4
seed_lons=np.array([np.ones(seed_number//3)*138.4674,np.ones(seed_number//3)*138.485,np.ones(seed_number//3)*138.462347]).ravel()
seed_lats=np.array([np.ones(seed_number//3)*-34.72596,np.ones(seed_number//3)*-34.96313,np.ones(seed_number//3)*-35.12587]).ravel()
seed_z=np.array([np.ones(seed_number//3)*-6,np.ones(seed_number//3)*-6,np.ones(seed_number//3)*-6]).ravel()
o.seed_elements(lon=seed_lons, lat=seed_lats, radius=0, number=seed_number,
                z=seed_z, time=seed_time)

# %%
seed_z.shape
# Out:
# (2016,)

# %%
o.run(steps=24*7*2*4,time_step=3600)
# Out:
# 17:02:30 INFO    opendrift.models.basemodel:2575: Fallback values will be used for the following variables which have no readers:
# 17:02:30 INFO    opendrift.models.basemodel:2578: 	x_wind: 0.000000
# 17:02:30 INFO    opendrift.models.basemodel:2578: 	y_wind: 0.000000
# 17:02:30 INFO    opendrift.models.basemodel:2578: 	sea_surface_wave_significant_height: 0.000000
# 17:02:30 INFO    opendrift.models.basemodel:2578: 	sea_surface_wave_stokes_drift_x_velocity: 0.000000
# 17:02:30 INFO    opendrift.models.basemodel:2578: 	sea_surface_wave_stokes_drift_y_velocity: 0.000000
# 17:02:30 INFO    opendrift.models.basemodel:2578: 	sea_surface_wave_period_at_variance_spectral_density_maximum: 0.000000
# 17:02:30 INFO    opendrift.models.basemodel:2578: 	sea_surface_wave_mean_period_from_variance_spectral_density_second_frequency_moment: 0.000000
# 17:02:30 INFO    opendrift.models.basemodel:2578: 	surface_downward_x_stress: 0.000000
# 17:02:30 INFO    opendrift.models.basemodel:2578: 	surface_downward_y_stress: 0.000000
# 17:02:30 INFO    opendrift.models.basemodel:2578: 	turbulent_kinetic_energy: 0.000000
# 17:02:30 INFO    opendrift.models.basemodel:2578: 	turbulent_generic_length_scale: 0.000000
# 17:02:30 INFO    opendrift.models.basemodel:2578: 	ocean_mixed_layer_thickness: 50.000000
# 17:02:30 INFO    opendrift.models.basemodel:2737: Adding a dynamical landmask with max. priority based on assumed maximum speed of 1 m/s. Adding a customised landmask may be faster...
# 17:02:40 INFO    opendrift.models.basemodel:1690: Using existing reader for land_binary_mask
# 17:02:40 INFO    opendrift.models.basemodel:1702: All points are in ocean
# 17:02:40 INFO    opendrift.models.basemodel:2866: 2018-01-01 00:00:00 - step 1 of 1344 - 12 active elements (0 deactivated)
# 17:02:41 INFO    opendrift.readers.reader_ROMS_native:403: Time: 0:00:00.378792
# 17:02:41 INFO    opendrift.models.basemodel:2866: 2018-01-01 01:00:00 - step 2 of 1344 - 24 active elements (0 deactivated)
# 17:02:41 INFO    opendrift.models.basemodel:2866: 2018-01-01 02:00:00 - step 3 of 1344 - 36 active elements (0 deactivated)
# 17:02:41 INFO    opendrift.models.basemodel:2866: 2018-01-01 03:00:00 - step 4 of 1344 - 48 active elements (0 deactivated)
# 17:02:41 INFO    opendrift.models.basemodel:2866: 2018-01-01 04:00:00 - step 5 of 1344 - 60 active elements (0 deactivated)
# 17:02:41 INFO    opendrift.models.basemodel:2866: 2018-01-01 05:00:00 - step 6 of 1344 - 72 active elements (0 deactivated)
# 17:02:42 INFO    opendrift.models.basemodel:2866: 2018-01-01 06:00:00 - step 7 of 1344 - 84 active elements (0 deactivated)
# 17:02:42 INFO    opendrift.models.basemodel:2866: 2018-01-01 07:00:00 - step 8 of 1344 - 96 active elements (0 deactivated)
# 17:02:42 INFO    opendrift.models.basemodel:2866: 2018-01-01 08:00:00 - step 9 of 1344 - 108 active elements (0 deactivated)
# 17:02:42 INFO    opendrift.models.basemodel:2866: 2018-01-01 09:00:00 - step 10 of 1344 - 120 active elements (0 deactivated)
# 17:02:42 INFO    opendrift.models.basemodel:2866: 2018-01-01 10:00:00 - step 11 of 1344 - 132 active elements (0 deactivated)
# 17:02:43 INFO    opendrift.models.basemodel:2866: 2018-01-01 11:00:00 - step 12 of 1344 - 144 active elements (0 deactivated)
# 17:02:43 INFO    opendrift.models.basemodel:2866: 2018-01-01 12:00:00 - step 13 of 1344 - 156 active elements (0 deactivated)
# 17:02:43 INFO    opendrift.models.basemodel:2866: 2018-01-01 13:00:00 - step 14 of 1344 - 168 active elements (0 deactivated)
# 17:02:43 INFO    opendrift.models.basemodel:2866: 2018-01-01 14:00:00 - step 15 of 1344 - 180 active elements (0 deactivated)
# 17:02:43 INFO    opendrift.models.basemodel:2866: 2018-01-01 15:00:00 - step 16 of 1344 - 192 active elements (0 deactivated)
# 17:02:44 INFO    opendrift.models.basemodel:2866: 2018-01-01 16:00:00 - step 17 of 1344 - 204 active elements (0 deactivated)
# 17:02:44 INFO    opendrift.models.basemodel:2866: 2018-01-01 17:00:00 - step 18 of 1344 - 216 active elements (0 deactivated)
# 17:02:44 INFO    opendrift.models.basemodel:2866: 2018-01-01 18:00:00 - step 19 of 1344 - 228 active elements (0 deactivated)
# 17:02:44 INFO    opendrift.models.basemodel:2866: 2018-01-01 19:00:00 - step 20 of 1344 - 240 active elements (0 deactivated)
# 17:02:44 INFO    opendrift.models.basemodel:2866: 2018-01-01 20:00:00 - step 21 of 1344 - 252 active elements (0 deactivated)
# 17:02:45 INFO    opendrift.models.basemodel:2866: 2018-01-01 21:00:00 - step 22 of 1344 - 264 active elements (0 deactivated)
# 17:02:45 INFO    opendrift.models.basemodel:2866: 2018-01-01 22:00:00 - step 23 of 1344 - 276 active elements (0 deactivated)
# 17:02:45 INFO    opendrift.models.basemodel:2866: 2018-01-01 23:00:00 - step 24 of 1344 - 288 active elements (0 deactivated)
# 17:02:45 INFO    opendrift.models.basemodel:2866: 2018-01-02 00:00:00 - step 25 of 1344 - 300 active elements (0 deactivated)
# 17:02:46 INFO    opendrift.models.basemodel:2866: 2018-01-02 01:00:00 - step 26 of 1344 - 312 active elements (0 deactivated)
# 17:02:46 INFO    opendrift.models.basemodel:2866: 2018-01-02 02:00:00 - step 27 of 1344 - 324 active elements (0 deactivated)
# 17:02:46 INFO    opendrift.models.basemodel:2866: 2018-01-02 03:00:00 - step 28 of 1344 - 336 active elements (0 deactivated)
# 17:02:46 INFO    opendrift.models.basemodel:2866: 2018-01-02 04:00:00 - step 29 of 1344 - 348 active elements (0 deactivated)
# 17:02:47 INFO    opendrift.models.basemodel:2866: 2018-01-02 05:00:00 - step 30 of 1344 - 360 active elements (0 deactivated)
# 17:02:47 INFO    opendrift.models.basemodel:2866: 2018-01-02 06:00:00 - step 31 of 1344 - 372 active elements (0 deactivated)
# 17:02:47 INFO    opendrift.models.basemodel:2866: 2018-01-02 07:00:00 - step 32 of 1344 - 384 active elements (0 deactivated)
# 17:02:47 INFO    opendrift.models.basemodel:2866: 2018-01-02 08:00:00 - step 33 of 1344 - 396 active elements (0 deactivated)
# 17:02:47 INFO    opendrift.models.basemodel:2866: 2018-01-02 09:00:00 - step 34 of 1344 - 408 active elements (0 deactivated)
# 17:02:48 INFO    opendrift.models.basemodel:2866: 2018-01-02 10:00:00 - step 35 of 1344 - 420 active elements (0 deactivated)
# 17:02:48 INFO    opendrift.models.basemodel:2866: 2018-01-02 11:00:00 - step 36 of 1344 - 432 active elements (0 deactivated)
# 17:02:48 INFO    opendrift.models.basemodel:2866: 2018-01-02 12:00:00 - step 37 of 1344 - 444 active elements (0 deactivated)
# 17:02:48 INFO    opendrift.models.basemodel:2866: 2018-01-02 13:00:00 - step 38 of 1344 - 456 active elements (0 deactivated)
# 17:02:48 INFO    opendrift.models.basemodel:2866: 2018-01-02 14:00:00 - step 39 of 1344 - 468 active elements (0 deactivated)
# 17:02:49 INFO    opendrift.models.basemodel:2866: 2018-01-02 15:00:00 - step 40 of 1344 - 480 active elements (0 deactivated)
# 17:02:49 INFO    opendrift.models.basemodel:2866: 2018-01-02 16:00:00 - step 41 of 1344 - 492 active elements (0 deactivated)
# 17:02:49 INFO    opendrift.models.basemodel:2866: 2018-01-02 17:00:00 - step 42 of 1344 - 504 active elements (0 deactivated)
# 17:02:49 INFO    opendrift.models.basemodel:2866: 2018-01-02 18:00:00 - step 43 of 1344 - 516 active elements (0 deactivated)
# 17:02:49 INFO    opendrift.models.basemodel:2866: 2018-01-02 19:00:00 - step 44 of 1344 - 528 active elements (0 deactivated)
# 17:02:50 INFO    opendrift.models.basemodel:2866: 2018-01-02 20:00:00 - step 45 of 1344 - 528 active elements (12 deactivated)
# 17:02:50 INFO    opendrift.models.basemodel:2866: 2018-01-02 21:00:00 - step 46 of 1344 - 540 active elements (12 deactivated)
# 17:02:50 INFO    opendrift.models.basemodel:2866: 2018-01-02 22:00:00 - step 47 of 1344 - 552 active elements (12 deactivated)
# 17:02:50 INFO    opendrift.models.basemodel:2866: 2018-01-02 23:00:00 - step 48 of 1344 - 564 active elements (12 deactivated)
# 17:02:50 INFO    opendrift.models.basemodel:2866: 2018-01-03 00:00:00 - step 49 of 1344 - 576 active elements (12 deactivated)
# 17:02:51 INFO    opendrift.models.basemodel:2866: 2018-01-03 01:00:00 - step 50 of 1344 - 588 active elements (12 deactivated)
# 17:02:51 INFO    opendrift.models.basemodel:2866: 2018-01-03 02:00:00 - step 51 of 1344 - 600 active elements (12 deactivated)
# 17:02:51 INFO    opendrift.models.basemodel:2866: 2018-01-03 03:00:00 - step 52 of 1344 - 612 active elements (12 deactivated)
# 17:02:51 INFO    opendrift.models.basemodel:2866: 2018-01-03 04:00:00 - step 53 of 1344 - 624 active elements (12 deactivated)
# 17:02:51 INFO    opendrift.models.basemodel:2866: 2018-01-03 05:00:00 - step 54 of 1344 - 636 active elements (12 deactivated)
# 17:02:52 INFO    opendrift.models.basemodel:2866: 2018-01-03 06:00:00 - step 55 of 1344 - 648 active elements (12 deactivated)
# 17:02:52 INFO    opendrift.models.basemodel:2866: 2018-01-03 07:00:00 - step 56 of 1344 - 648 active elements (24 deactivated)
# 17:02:52 WARNING opendrift.readers.basereader.structured:286: Data block from roms native not large enough to cover element positions within timestep. Buffer size (5) must be increased. See `Variables.set_buffer_size`.
# 17:02:52 INFO    opendrift.models.basemodel:2866: 2018-01-03 08:00:00 - step 57 of 1344 - 600 active elements (84 deactivated)
# 17:02:52 WARNING opendrift.readers.basereader.structured:286: Data block from roms native not large enough to cover element positions within timestep. Buffer size (5) must be increased. See `Variables.set_buffer_size`.
# 17:02:52 INFO    opendrift.models.basemodel:2866: 2018-01-03 09:00:00 - step 58 of 1344 - 588 active elements (108 deactivated)
# 17:02:53 INFO    opendrift.models.basemodel:2866: 2018-01-03 10:00:00 - step 59 of 1344 - 600 active elements (108 deactivated)
# 17:02:53 INFO    opendrift.models.basemodel:2866: 2018-01-03 11:00:00 - step 60 of 1344 - 600 active elements (120 deactivated)
# 17:02:53 INFO    opendrift.models.basemodel:2866: 2018-01-03 12:00:00 - step 61 of 1344 - 612 active elements (120 deactivated)
# 17:02:53 INFO    opendrift.models.basemodel:2866: 2018-01-03 13:00:00 - step 62 of 1344 - 624 active elements (120 deactivated)
# 17:02:53 INFO    opendrift.models.basemodel:2866: 2018-01-03 14:00:00 - step 63 of 1344 - 636 active elements (120 deactivated)
# 17:02:54 INFO    opendrift.models.basemodel:2866: 2018-01-03 15:00:00 - step 64 of 1344 - 648 active elements (120 deactivated)
# 17:02:54 INFO    opendrift.models.basemodel:2866: 2018-01-03 16:00:00 - step 65 of 1344 - 660 active elements (120 deactivated)
# 17:02:54 INFO    opendrift.models.basemodel:2866: 2018-01-03 17:00:00 - step 66 of 1344 - 672 active elements (120 deactivated)
# 17:02:54 INFO    opendrift.models.basemodel:2866: 2018-01-03 18:00:00 - step 67 of 1344 - 648 active elements (156 deactivated)
# 17:02:54 INFO    opendrift.models.basemodel:2866: 2018-01-03 19:00:00 - step 68 of 1344 - 612 active elements (204 deactivated)
# 17:02:55 INFO    opendrift.models.basemodel:2866: 2018-01-03 20:00:00 - step 69 of 1344 - 600 active elements (228 deactivated)
# 17:02:55 INFO    opendrift.models.basemodel:2866: 2018-01-03 21:00:00 - step 70 of 1344 - 564 active elements (276 deactivated)
# 17:02:55 INFO    opendrift.models.basemodel:2866: 2018-01-03 22:00:00 - step 71 of 1344 - 576 active elements (276 deactivated)
# 17:02:55 INFO    opendrift.models.basemodel:2866: 2018-01-03 23:00:00 - step 72 of 1344 - 588 active elements (276 deactivated)
# 17:02:56 INFO    opendrift.models.basemodel:2866: 2018-01-04 00:00:00 - step 73 of 1344 - 600 active elements (276 deactivated)
# 17:02:56 INFO    opendrift.models.basemodel:2866: 2018-01-04 01:00:00 - step 74 of 1344 - 600 active elements (288 deactivated)
# 17:02:56 INFO    opendrift.models.basemodel:2866: 2018-01-04 02:00:00 - step 75 of 1344 - 576 active elements (324 deactivated)
# 17:02:56 INFO    opendrift.models.basemodel:2866: 2018-01-04 03:00:00 - step 76 of 1344 - 576 active elements (336 deactivated)
# 17:02:57 INFO    opendrift.models.basemodel:2866: 2018-01-04 04:00:00 - step 77 of 1344 - 576 active elements (348 deactivated)
# 17:02:57 INFO    opendrift.models.basemodel:2866: 2018-01-04 05:00:00 - step 78 of 1344 - 588 active elements (348 deactivated)
# 17:02:57 INFO    opendrift.models.basemodel:2866: 2018-01-04 06:00:00 - step 79 of 1344 - 600 active elements (348 deactivated)
# 17:02:57 INFO    opendrift.models.basemodel:2866: 2018-01-04 07:00:00 - step 80 of 1344 - 588 active elements (372 deactivated)
# 17:02:57 INFO    opendrift.models.basemodel:2866: 2018-01-04 08:00:00 - step 81 of 1344 - 564 active elements (408 deactivated)
# 17:02:58 INFO    opendrift.models.basemodel:2866: 2018-01-04 09:00:00 - step 82 of 1344 - 540 active elements (444 deactivated)
# 17:02:58 INFO    opendrift.models.basemodel:2866: 2018-01-04 10:00:00 - step 83 of 1344 - 552 active elements (444 deactivated)
# 17:02:58 INFO    opendrift.models.basemodel:2866: 2018-01-04 11:00:00 - step 84 of 1344 - 564 active elements (444 deactivated)
# 17:02:58 INFO    opendrift.models.basemodel:2866: 2018-01-04 12:00:00 - step 85 of 1344 - 576 active elements (444 deactivated)
# 17:02:59 INFO    opendrift.models.basemodel:2866: 2018-01-04 13:00:00 - step 86 of 1344 - 588 active elements (444 deactivated)
# 17:02:59 INFO    opendrift.models.basemodel:2866: 2018-01-04 14:00:00 - step 87 of 1344 - 600 active elements (444 deactivated)
# 17:02:59 INFO    opendrift.models.basemodel:2866: 2018-01-04 15:00:00 - step 88 of 1344 - 612 active elements (444 deactivated)
# 17:02:59 INFO    opendrift.models.basemodel:2866: 2018-01-04 16:00:00 - step 89 of 1344 - 624 active elements (444 deactivated)
# 17:02:59 INFO    opendrift.models.basemodel:2866: 2018-01-04 17:00:00 - step 90 of 1344 - 636 active elements (444 deactivated)
# 17:03:00 INFO    opendrift.models.basemodel:2866: 2018-01-04 18:00:00 - step 91 of 1344 - 648 active elements (444 deactivated)
# 17:03:00 INFO    opendrift.models.basemodel:2866: 2018-01-04 19:00:00 - step 92 of 1344 - 660 active elements (444 deactivated)
# 17:03:00 INFO    opendrift.models.basemodel:2866: 2018-01-04 20:00:00 - step 93 of 1344 - 672 active elements (444 deactivated)
# 17:03:00 INFO    opendrift.models.basemodel:2866: 2018-01-04 21:00:00 - step 94 of 1344 - 684 active elements (444 deactivated)
# 17:03:00 INFO    opendrift.models.basemodel:2866: 2018-01-04 22:00:00 - step 95 of 1344 - 696 active elements (444 deactivated)
# 17:03:01 INFO    opendrift.models.basemodel:2866: 2018-01-04 23:00:00 - step 96 of 1344 - 708 active elements (444 deactivated)
# 17:03:01 INFO    opendrift.models.basemodel:2866: 2018-01-05 00:00:00 - step 97 of 1344 - 720 active elements (444 deactivated)
# 17:03:01 INFO    opendrift.models.basemodel:2866: 2018-01-05 01:00:00 - step 98 of 1344 - 732 active elements (444 deactivated)
# 17:03:01 INFO    opendrift.models.basemodel:2866: 2018-01-05 02:00:00 - step 99 of 1344 - 744 active elements (444 deactivated)
# 17:03:01 INFO    opendrift.models.basemodel:2866: 2018-01-05 03:00:00 - step 100 of 1344 - 744 active elements (456 deactivated)
# 17:03:02 INFO    opendrift.models.basemodel:2866: 2018-01-05 04:00:00 - step 101 of 1344 - 756 active elements (456 deactivated)
# 17:03:02 INFO    opendrift.models.basemodel:2866: 2018-01-05 05:00:00 - step 102 of 1344 - 768 active elements (456 deactivated)
# 17:03:02 INFO    opendrift.models.basemodel:2866: 2018-01-05 06:00:00 - step 103 of 1344 - 780 active elements (456 deactivated)
# 17:03:02 INFO    opendrift.models.basemodel:2866: 2018-01-05 07:00:00 - step 104 of 1344 - 792 active elements (456 deactivated)
# 17:03:02 INFO    opendrift.models.basemodel:2866: 2018-01-05 08:00:00 - step 105 of 1344 - 804 active elements (456 deactivated)
# 17:03:03 INFO    opendrift.models.basemodel:2866: 2018-01-05 09:00:00 - step 106 of 1344 - 816 active elements (456 deactivated)
# 17:03:03 INFO    opendrift.models.basemodel:2866: 2018-01-05 10:00:00 - step 107 of 1344 - 828 active elements (456 deactivated)
# 17:03:03 INFO    opendrift.models.basemodel:2866: 2018-01-05 11:00:00 - step 108 of 1344 - 840 active elements (456 deactivated)
# 17:03:03 INFO    opendrift.models.basemodel:2866: 2018-01-05 12:00:00 - step 109 of 1344 - 852 active elements (456 deactivated)
# 17:03:03 INFO    opendrift.models.basemodel:2866: 2018-01-05 13:00:00 - step 110 of 1344 - 864 active elements (456 deactivated)
# 17:03:04 INFO    opendrift.models.basemodel:2866: 2018-01-05 14:00:00 - step 111 of 1344 - 876 active elements (456 deactivated)
# 17:03:04 INFO    opendrift.models.basemodel:2866: 2018-01-05 15:00:00 - step 112 of 1344 - 888 active elements (456 deactivated)
# 17:03:04 WARNING opendrift.readers.basereader.structured:286: Data block from roms native not large enough to cover element positions within timestep. Buffer size (5) must be increased. See `Variables.set_buffer_size`.
# 17:03:04 INFO    opendrift.models.basemodel:2866: 2018-01-05 16:00:00 - step 113 of 1344 - 900 active elements (456 deactivated)
# 17:03:04 WARNING opendrift.readers.basereader.structured:286: Data block from roms native not large enough to cover element positions within timestep. Buffer size (5) must be increased. See `Variables.set_buffer_size`.
# 17:03:04 INFO    opendrift.models.basemodel:2866: 2018-01-05 17:00:00 - step 114 of 1344 - 912 active elements (456 deactivated)
# 17:03:05 INFO    opendrift.models.basemodel:2866: 2018-01-05 18:00:00 - step 115 of 1344 - 924 active elements (456 deactivated)
# 17:03:05 INFO    opendrift.models.basemodel:2866: 2018-01-05 19:00:00 - step 116 of 1344 - 936 active elements (456 deactivated)
# 17:03:05 INFO    opendrift.models.basemodel:2866: 2018-01-05 20:00:00 - step 117 of 1344 - 948 active elements (456 deactivated)
# 17:03:05 INFO    opendrift.models.basemodel:2866: 2018-01-05 21:00:00 - step 118 of 1344 - 960 active elements (456 deactivated)
# 17:03:05 INFO    opendrift.models.basemodel:2866: 2018-01-05 22:00:00 - step 119 of 1344 - 972 active elements (456 deactivated)
# 17:03:06 INFO    opendrift.models.basemodel:2866: 2018-01-05 23:00:00 - step 120 of 1344 - 984 active elements (456 deactivated)
# 17:03:06 INFO    opendrift.models.basemodel:2866: 2018-01-06 00:00:00 - step 121 of 1344 - 996 active elements (456 deactivated)
# 17:03:06 INFO    opendrift.models.basemodel:2866: 2018-01-06 01:00:00 - step 122 of 1344 - 1008 active elements (456 deactivated)
# 17:03:06 INFO    opendrift.models.basemodel:2866: 2018-01-06 02:00:00 - step 123 of 1344 - 1020 active elements (456 deactivated)
# 17:03:07 INFO    opendrift.models.basemodel:2866: 2018-01-06 03:00:00 - step 124 of 1344 - 1032 active elements (456 deactivated)
# 17:03:07 INFO    opendrift.models.basemodel:2866: 2018-01-06 04:00:00 - step 125 of 1344 - 1044 active elements (456 deactivated)
# 17:03:07 INFO    opendrift.models.basemodel:2866: 2018-01-06 05:00:00 - step 126 of 1344 - 1056 active elements (456 deactivated)
# 17:03:07 INFO    opendrift.models.basemodel:2866: 2018-01-06 06:00:00 - step 127 of 1344 - 1068 active elements (456 deactivated)
# 17:03:08 INFO    opendrift.models.basemodel:2866: 2018-01-06 07:00:00 - step 128 of 1344 - 1080 active elements (456 deactivated)
# 17:03:08 INFO    opendrift.models.basemodel:2866: 2018-01-06 08:00:00 - step 129 of 1344 - 1092 active elements (456 deactivated)
# 17:03:08 INFO    opendrift.models.basemodel:2866: 2018-01-06 09:00:00 - step 130 of 1344 - 1104 active elements (456 deactivated)
# 17:03:09 INFO    opendrift.models.basemodel:2866: 2018-01-06 10:00:00 - step 131 of 1344 - 1116 active elements (456 deactivated)
# 17:03:09 INFO    opendrift.models.basemodel:2866: 2018-01-06 11:00:00 - step 132 of 1344 - 1128 active elements (456 deactivated)
# 17:03:09 INFO    opendrift.models.basemodel:2866: 2018-01-06 12:00:00 - step 133 of 1344 - 1140 active elements (456 deactivated)
# 17:03:09 INFO    opendrift.models.basemodel:2866: 2018-01-06 13:00:00 - step 134 of 1344 - 1152 active elements (456 deactivated)
# 17:03:10 INFO    opendrift.models.basemodel:2866: 2018-01-06 14:00:00 - step 135 of 1344 - 1164 active elements (456 deactivated)
# 17:03:10 INFO    opendrift.models.basemodel:2866: 2018-01-06 15:00:00 - step 136 of 1344 - 1176 active elements (456 deactivated)
# 17:03:10 INFO    opendrift.models.basemodel:2866: 2018-01-06 16:00:00 - step 137 of 1344 - 1188 active elements (456 deactivated)
# 17:03:10 INFO    opendrift.models.basemodel:2866: 2018-01-06 17:00:00 - step 138 of 1344 - 1200 active elements (456 deactivated)
# 17:03:10 INFO    opendrift.models.basemodel:2866: 2018-01-06 18:00:00 - step 139 of 1344 - 1212 active elements (456 deactivated)
# 17:03:11 INFO    opendrift.models.basemodel:2866: 2018-01-06 19:00:00 - step 140 of 1344 - 1224 active elements (456 deactivated)
# 17:03:11 INFO    opendrift.models.basemodel:2866: 2018-01-06 20:00:00 - step 141 of 1344 - 1236 active elements (456 deactivated)
# 17:03:11 INFO    opendrift.models.basemodel:2866: 2018-01-06 21:00:00 - step 142 of 1344 - 1248 active elements (456 deactivated)
# 17:03:11 INFO    opendrift.models.basemodel:2866: 2018-01-06 22:00:00 - step 143 of 1344 - 1260 active elements (456 deactivated)
# 17:03:12 INFO    opendrift.models.basemodel:2866: 2018-01-06 23:00:00 - step 144 of 1344 - 1272 active elements (456 deactivated)
# 17:03:12 INFO    opendrift.models.basemodel:2866: 2018-01-07 00:00:00 - step 145 of 1344 - 1284 active elements (456 deactivated)
# 17:03:12 INFO    opendrift.models.basemodel:2866: 2018-01-07 01:00:00 - step 146 of 1344 - 1296 active elements (456 deactivated)
# 17:03:12 INFO    opendrift.models.basemodel:2866: 2018-01-07 02:00:00 - step 147 of 1344 - 1308 active elements (456 deactivated)
# 17:03:13 INFO    opendrift.models.basemodel:2866: 2018-01-07 03:00:00 - step 148 of 1344 - 1320 active elements (456 deactivated)
# 17:03:13 INFO    opendrift.models.basemodel:2866: 2018-01-07 04:00:00 - step 149 of 1344 - 1332 active elements (456 deactivated)
# 17:03:13 INFO    opendrift.models.basemodel:2866: 2018-01-07 05:00:00 - step 150 of 1344 - 1344 active elements (456 deactivated)
# 17:03:13 INFO    opendrift.models.basemodel:2866: 2018-01-07 06:00:00 - step 151 of 1344 - 1356 active elements (456 deactivated)
# 17:03:14 INFO    opendrift.models.basemodel:2866: 2018-01-07 07:00:00 - step 152 of 1344 - 1368 active elements (456 deactivated)
# 17:03:14 INFO    opendrift.models.basemodel:2866: 2018-01-07 08:00:00 - step 153 of 1344 - 1380 active elements (456 deactivated)
# 17:03:14 INFO    opendrift.models.basemodel:2866: 2018-01-07 09:00:00 - step 154 of 1344 - 1392 active elements (456 deactivated)
# 17:03:14 INFO    opendrift.models.basemodel:2866: 2018-01-07 10:00:00 - step 155 of 1344 - 1404 active elements (456 deactivated)
# 17:03:15 INFO    opendrift.models.basemodel:2866: 2018-01-07 11:00:00 - step 156 of 1344 - 1416 active elements (456 deactivated)
# 17:03:15 INFO    opendrift.models.basemodel:2866: 2018-01-07 12:00:00 - step 157 of 1344 - 1428 active elements (456 deactivated)
# 17:03:15 INFO    opendrift.models.basemodel:2866: 2018-01-07 13:00:00 - step 158 of 1344 - 1440 active elements (456 deactivated)
# 17:03:15 INFO    opendrift.models.basemodel:2866: 2018-01-07 14:00:00 - step 159 of 1344 - 1452 active elements (456 deactivated)
# 17:03:15 INFO    opendrift.models.basemodel:2866: 2018-01-07 15:00:00 - step 160 of 1344 - 1464 active elements (456 deactivated)
# 17:03:16 INFO    opendrift.models.basemodel:2866: 2018-01-07 16:00:00 - step 161 of 1344 - 1476 active elements (456 deactivated)
# 17:03:16 INFO    opendrift.models.basemodel:2866: 2018-01-07 17:00:00 - step 162 of 1344 - 1488 active elements (456 deactivated)
# 17:03:16 INFO    opendrift.models.basemodel:2866: 2018-01-07 18:00:00 - step 163 of 1344 - 1500 active elements (456 deactivated)
# 17:03:17 INFO    opendrift.models.basemodel:2866: 2018-01-07 19:00:00 - step 164 of 1344 - 1512 active elements (456 deactivated)
# 17:03:17 INFO    opendrift.models.basemodel:2866: 2018-01-07 20:00:00 - step 165 of 1344 - 1524 active elements (456 deactivated)
# 17:03:17 INFO    opendrift.models.basemodel:2866: 2018-01-07 21:00:00 - step 166 of 1344 - 1536 active elements (456 deactivated)
# 17:03:17 INFO    opendrift.models.basemodel:2866: 2018-01-07 22:00:00 - step 167 of 1344 - 1524 active elements (480 deactivated)
# 17:03:18 INFO    opendrift.models.basemodel:2866: 2018-01-07 23:00:00 - step 168 of 1344 - 1536 active elements (480 deactivated)
# 17:03:18 INFO    opendrift.models.basemodel:2866: 2018-01-08 00:00:00 - step 169 of 1344 - 1536 active elements (480 deactivated)
# 17:03:18 INFO    opendrift.models.basemodel:2866: 2018-01-08 01:00:00 - step 170 of 1344 - 1536 active elements (480 deactivated)
# 17:03:18 INFO    opendrift.models.basemodel:2866: 2018-01-08 02:00:00 - step 171 of 1344 - 1536 active elements (480 deactivated)
# 17:03:19 INFO    opendrift.models.basemodel:2866: 2018-01-08 03:00:00 - step 172 of 1344 - 1536 active elements (480 deactivated)
# 17:03:19 INFO    opendrift.models.basemodel:2866: 2018-01-08 04:00:00 - step 173 of 1344 - 1536 active elements (480 deactivated)
# 17:03:19 INFO    opendrift.models.basemodel:2866: 2018-01-08 05:00:00 - step 174 of 1344 - 1536 active elements (480 deactivated)
# 17:03:19 INFO    opendrift.models.basemodel:2866: 2018-01-08 06:00:00 - step 175 of 1344 - 1536 active elements (480 deactivated)
# 17:03:20 INFO    opendrift.models.basemodel:2866: 2018-01-08 07:00:00 - step 176 of 1344 - 1536 active elements (480 deactivated)
# 17:03:20 INFO    opendrift.models.basemodel:2866: 2018-01-08 08:00:00 - step 177 of 1344 - 1536 active elements (480 deactivated)
# 17:03:20 INFO    opendrift.models.basemodel:2866: 2018-01-08 09:00:00 - step 178 of 1344 - 1536 active elements (480 deactivated)
# 17:03:20 INFO    opendrift.models.basemodel:2866: 2018-01-08 10:00:00 - step 179 of 1344 - 1536 active elements (480 deactivated)
# 17:03:21 INFO    opendrift.models.basemodel:2866: 2018-01-08 11:00:00 - step 180 of 1344 - 1524 active elements (492 deactivated)
# 17:03:21 INFO    opendrift.models.basemodel:2866: 2018-01-08 12:00:00 - step 181 of 1344 - 1512 active elements (504 deactivated)
# 17:03:21 INFO    opendrift.models.basemodel:2866: 2018-01-08 13:00:00 - step 182 of 1344 - 1488 active elements (528 deactivated)
# 17:03:21 INFO    opendrift.models.basemodel:2866: 2018-01-08 14:00:00 - step 183 of 1344 - 1488 active elements (528 deactivated)
# 17:03:22 INFO    opendrift.models.basemodel:2866: 2018-01-08 15:00:00 - step 184 of 1344 - 1488 active elements (528 deactivated)
# 17:03:22 INFO    opendrift.models.basemodel:2866: 2018-01-08 16:00:00 - step 185 of 1344 - 1488 active elements (528 deactivated)
# 17:03:22 INFO    opendrift.models.basemodel:2866: 2018-01-08 17:00:00 - step 186 of 1344 - 1488 active elements (528 deactivated)
# 17:03:22 INFO    opendrift.models.basemodel:2866: 2018-01-08 18:00:00 - step 187 of 1344 - 1488 active elements (528 deactivated)
# 17:03:23 INFO    opendrift.models.basemodel:2866: 2018-01-08 19:00:00 - step 188 of 1344 - 1488 active elements (528 deactivated)
# 17:03:23 INFO    opendrift.models.basemodel:2866: 2018-01-08 20:00:00 - step 189 of 1344 - 1488 active elements (528 deactivated)
# 17:03:23 INFO    opendrift.models.basemodel:2866: 2018-01-08 21:00:00 - step 190 of 1344 - 1464 active elements (552 deactivated)
# 17:03:23 INFO    opendrift.models.basemodel:2866: 2018-01-08 22:00:00 - step 191 of 1344 - 1452 active elements (564 deactivated)
# 17:03:23 INFO    opendrift.models.basemodel:2866: 2018-01-08 23:00:00 - step 192 of 1344 - 1440 active elements (576 deactivated)
# 17:03:24 INFO    opendrift.models.basemodel:2866: 2018-01-09 00:00:00 - step 193 of 1344 - 1428 active elements (588 deactivated)
# 17:03:24 INFO    opendrift.models.basemodel:2866: 2018-01-09 01:00:00 - step 194 of 1344 - 1404 active elements (612 deactivated)
# 17:03:24 INFO    opendrift.models.basemodel:2866: 2018-01-09 02:00:00 - step 195 of 1344 - 1404 active elements (612 deactivated)
# 17:03:24 INFO    opendrift.models.basemodel:2866: 2018-01-09 03:00:00 - step 196 of 1344 - 1404 active elements (612 deactivated)
# 17:03:25 INFO    opendrift.models.basemodel:2866: 2018-01-09 04:00:00 - step 197 of 1344 - 1404 active elements (612 deactivated)
# 17:03:25 INFO    opendrift.models.basemodel:2866: 2018-01-09 05:00:00 - step 198 of 1344 - 1404 active elements (612 deactivated)
# 17:03:25 INFO    opendrift.models.basemodel:2866: 2018-01-09 06:00:00 - step 199 of 1344 - 1404 active elements (612 deactivated)
# 17:03:25 INFO    opendrift.models.basemodel:2866: 2018-01-09 07:00:00 - step 200 of 1344 - 1404 active elements (612 deactivated)
# 17:03:26 INFO    opendrift.models.basemodel:2866: 2018-01-09 08:00:00 - step 201 of 1344 - 1404 active elements (612 deactivated)
# 17:03:26 INFO    opendrift.models.basemodel:2866: 2018-01-09 09:00:00 - step 202 of 1344 - 1392 active elements (624 deactivated)
# 17:03:26 INFO    opendrift.models.basemodel:2866: 2018-01-09 10:00:00 - step 203 of 1344 - 1380 active elements (636 deactivated)
# 17:03:26 INFO    opendrift.models.basemodel:2866: 2018-01-09 11:00:00 - step 204 of 1344 - 1320 active elements (696 deactivated)
# 17:03:27 INFO    opendrift.models.basemodel:2866: 2018-01-09 12:00:00 - step 205 of 1344 - 1308 active elements (708 deactivated)
# 17:03:27 INFO    opendrift.models.basemodel:2866: 2018-01-09 13:00:00 - step 206 of 1344 - 1284 active elements (732 deactivated)
# 17:03:27 INFO    opendrift.models.basemodel:2866: 2018-01-09 14:00:00 - step 207 of 1344 - 1284 active elements (732 deactivated)
# 17:03:27 INFO    opendrift.models.basemodel:2866: 2018-01-09 15:00:00 - step 208 of 1344 - 1284 active elements (732 deactivated)
# 17:03:28 INFO    opendrift.models.basemodel:2866: 2018-01-09 16:00:00 - step 209 of 1344 - 1284 active elements (732 deactivated)
# 17:03:28 INFO    opendrift.models.basemodel:2866: 2018-01-09 17:00:00 - step 210 of 1344 - 1284 active elements (732 deactivated)
# 17:03:28 INFO    opendrift.models.basemodel:2866: 2018-01-09 18:00:00 - step 211 of 1344 - 1284 active elements (732 deactivated)
# 17:03:28 INFO    opendrift.models.basemodel:2866: 2018-01-09 19:00:00 - step 212 of 1344 - 1284 active elements (732 deactivated)
# 17:03:29 INFO    opendrift.models.basemodel:2866: 2018-01-09 20:00:00 - step 213 of 1344 - 1284 active elements (732 deactivated)
# 17:03:29 INFO    opendrift.models.basemodel:2866: 2018-01-09 21:00:00 - step 214 of 1344 - 1272 active elements (744 deactivated)
# 17:03:29 INFO    opendrift.models.basemodel:2866: 2018-01-09 22:00:00 - step 215 of 1344 - 1272 active elements (744 deactivated)
# 17:03:29 INFO    opendrift.models.basemodel:2866: 2018-01-09 23:00:00 - step 216 of 1344 - 1260 active elements (756 deactivated)
# 17:03:30 INFO    opendrift.models.basemodel:2866: 2018-01-10 00:00:00 - step 217 of 1344 - 1212 active elements (804 deactivated)
# 17:03:30 INFO    opendrift.models.basemodel:2866: 2018-01-10 01:00:00 - step 218 of 1344 - 1200 active elements (816 deactivated)
# 17:03:30 INFO    opendrift.models.basemodel:2866: 2018-01-10 02:00:00 - step 219 of 1344 - 1188 active elements (828 deactivated)
# 17:03:30 INFO    opendrift.models.basemodel:2866: 2018-01-10 03:00:00 - step 220 of 1344 - 1188 active elements (828 deactivated)
# 17:03:31 INFO    opendrift.models.basemodel:2866: 2018-01-10 04:00:00 - step 221 of 1344 - 1188 active elements (828 deactivated)
# 17:03:31 INFO    opendrift.models.basemodel:2866: 2018-01-10 05:00:00 - step 222 of 1344 - 1188 active elements (828 deactivated)
# 17:03:31 INFO    opendrift.models.basemodel:2866: 2018-01-10 06:00:00 - step 223 of 1344 - 1188 active elements (828 deactivated)
# 17:03:31 INFO    opendrift.models.basemodel:2866: 2018-01-10 07:00:00 - step 224 of 1344 - 1188 active elements (828 deactivated)
# 17:03:31 INFO    opendrift.models.basemodel:2866: 2018-01-10 08:00:00 - step 225 of 1344 - 1188 active elements (828 deactivated)
# 17:03:32 INFO    opendrift.models.basemodel:2866: 2018-01-10 09:00:00 - step 226 of 1344 - 1188 active elements (828 deactivated)
# 17:03:32 INFO    opendrift.models.basemodel:2866: 2018-01-10 10:00:00 - step 227 of 1344 - 1152 active elements (864 deactivated)
# 17:03:32 INFO    opendrift.models.basemodel:2866: 2018-01-10 11:00:00 - step 228 of 1344 - 1128 active elements (888 deactivated)
# 17:03:32 INFO    opendrift.models.basemodel:2866: 2018-01-10 12:00:00 - step 229 of 1344 - 1104 active elements (912 deactivated)
# 17:03:33 INFO    opendrift.models.basemodel:2866: 2018-01-10 13:00:00 - step 230 of 1344 - 1092 active elements (924 deactivated)
# 17:03:33 INFO    opendrift.models.basemodel:2866: 2018-01-10 14:00:00 - step 231 of 1344 - 1092 active elements (924 deactivated)
# 17:03:33 INFO    opendrift.models.basemodel:2866: 2018-01-10 15:00:00 - step 232 of 1344 - 1092 active elements (924 deactivated)
# 17:03:33 INFO    opendrift.models.basemodel:2866: 2018-01-10 16:00:00 - step 233 of 1344 - 1092 active elements (924 deactivated)
# 17:03:34 INFO    opendrift.models.basemodel:2866: 2018-01-10 17:00:00 - step 234 of 1344 - 1092 active elements (924 deactivated)
# 17:03:34 INFO    opendrift.models.basemodel:2866: 2018-01-10 18:00:00 - step 235 of 1344 - 1092 active elements (924 deactivated)
# 17:03:34 INFO    opendrift.models.basemodel:2866: 2018-01-10 19:00:00 - step 236 of 1344 - 1092 active elements (924 deactivated)
# 17:03:34 INFO    opendrift.models.basemodel:2866: 2018-01-10 20:00:00 - step 237 of 1344 - 1092 active elements (924 deactivated)
# 17:03:34 INFO    opendrift.models.basemodel:2866: 2018-01-10 21:00:00 - step 238 of 1344 - 1092 active elements (924 deactivated)
# 17:03:35 INFO    opendrift.models.basemodel:2866: 2018-01-10 22:00:00 - step 239 of 1344 - 1092 active elements (924 deactivated)
# 17:03:35 INFO    opendrift.models.basemodel:2866: 2018-01-10 23:00:00 - step 240 of 1344 - 1092 active elements (924 deactivated)
# 17:03:35 INFO    opendrift.models.basemodel:2866: 2018-01-11 00:00:00 - step 241 of 1344 - 1092 active elements (924 deactivated)
# 17:03:35 INFO    opendrift.models.basemodel:2866: 2018-01-11 01:00:00 - step 242 of 1344 - 1092 active elements (924 deactivated)
# 17:03:36 INFO    opendrift.models.basemodel:2866: 2018-01-11 02:00:00 - step 243 of 1344 - 1092 active elements (924 deactivated)
# 17:03:36 INFO    opendrift.models.basemodel:2866: 2018-01-11 03:00:00 - step 244 of 1344 - 1092 active elements (924 deactivated)
# 17:03:36 INFO    opendrift.models.basemodel:2866: 2018-01-11 04:00:00 - step 245 of 1344 - 1092 active elements (924 deactivated)
# 17:03:36 INFO    opendrift.models.basemodel:2866: 2018-01-11 05:00:00 - step 246 of 1344 - 1092 active elements (924 deactivated)
# 17:03:37 INFO    opendrift.models.basemodel:2866: 2018-01-11 06:00:00 - step 247 of 1344 - 1092 active elements (924 deactivated)
# 17:03:37 INFO    opendrift.models.basemodel:2866: 2018-01-11 07:00:00 - step 248 of 1344 - 1092 active elements (924 deactivated)
# 17:03:37 INFO    opendrift.models.basemodel:2866: 2018-01-11 08:00:00 - step 249 of 1344 - 1092 active elements (924 deactivated)
# 17:03:37 INFO    opendrift.models.basemodel:2866: 2018-01-11 09:00:00 - step 250 of 1344 - 1092 active elements (924 deactivated)
# 17:03:37 INFO    opendrift.models.basemodel:2866: 2018-01-11 10:00:00 - step 251 of 1344 - 1092 active elements (924 deactivated)
# 17:03:38 INFO    opendrift.models.basemodel:2866: 2018-01-11 11:00:00 - step 252 of 1344 - 1092 active elements (924 deactivated)
# 17:03:38 INFO    opendrift.models.basemodel:2866: 2018-01-11 12:00:00 - step 253 of 1344 - 1092 active elements (924 deactivated)
# 17:03:38 INFO    opendrift.models.basemodel:2866: 2018-01-11 13:00:00 - step 254 of 1344 - 1080 active elements (936 deactivated)
# 17:03:38 INFO    opendrift.models.basemodel:2866: 2018-01-11 14:00:00 - step 255 of 1344 - 1056 active elements (960 deactivated)
# 17:03:39 INFO    opendrift.models.basemodel:2866: 2018-01-11 15:00:00 - step 256 of 1344 - 1056 active elements (960 deactivated)
# 17:03:39 INFO    opendrift.models.basemodel:2866: 2018-01-11 16:00:00 - step 257 of 1344 - 1056 active elements (960 deactivated)
# 17:03:39 INFO    opendrift.models.basemodel:2866: 2018-01-11 17:00:00 - step 258 of 1344 - 1056 active elements (960 deactivated)
# 17:03:39 INFO    opendrift.models.basemodel:2866: 2018-01-11 18:00:00 - step 259 of 1344 - 1056 active elements (960 deactivated)
# 17:03:40 INFO    opendrift.models.basemodel:2866: 2018-01-11 19:00:00 - step 260 of 1344 - 1056 active elements (960 deactivated)
# 17:03:40 INFO    opendrift.models.basemodel:2866: 2018-01-11 20:00:00 - step 261 of 1344 - 1056 active elements (960 deactivated)
# 17:03:40 INFO    opendrift.models.basemodel:2866: 2018-01-11 21:00:00 - step 262 of 1344 - 1056 active elements (960 deactivated)
# 17:03:40 INFO    opendrift.models.basemodel:2866: 2018-01-11 22:00:00 - step 263 of 1344 - 1056 active elements (960 deactivated)
# 17:03:40 INFO    opendrift.models.basemodel:2866: 2018-01-11 23:00:00 - step 264 of 1344 - 1056 active elements (960 deactivated)
# 17:03:41 INFO    opendrift.models.basemodel:2866: 2018-01-12 00:00:00 - step 265 of 1344 - 1056 active elements (960 deactivated)
# 17:03:41 INFO    opendrift.models.basemodel:2866: 2018-01-12 01:00:00 - step 266 of 1344 - 1056 active elements (960 deactivated)
# 17:03:41 INFO    opendrift.models.basemodel:2866: 2018-01-12 02:00:00 - step 267 of 1344 - 1056 active elements (960 deactivated)
# 17:03:41 INFO    opendrift.models.basemodel:2866: 2018-01-12 03:00:00 - step 268 of 1344 - 1056 active elements (960 deactivated)
# 17:03:42 INFO    opendrift.models.basemodel:2866: 2018-01-12 04:00:00 - step 269 of 1344 - 1056 active elements (960 deactivated)
# 17:03:42 INFO    opendrift.models.basemodel:2866: 2018-01-12 05:00:00 - step 270 of 1344 - 1056 active elements (960 deactivated)
# 17:03:42 INFO    opendrift.models.basemodel:2866: 2018-01-12 06:00:00 - step 271 of 1344 - 1032 active elements (984 deactivated)
# 17:03:42 INFO    opendrift.models.basemodel:2866: 2018-01-12 07:00:00 - step 272 of 1344 - 1020 active elements (996 deactivated)
# 17:03:43 INFO    opendrift.models.basemodel:2866: 2018-01-12 08:00:00 - step 273 of 1344 - 1008 active elements (1008 deactivated)
# 17:03:43 INFO    opendrift.models.basemodel:2866: 2018-01-12 09:00:00 - step 274 of 1344 - 1008 active elements (1008 deactivated)
# 17:03:43 INFO    opendrift.models.basemodel:2866: 2018-01-12 10:00:00 - step 275 of 1344 - 1008 active elements (1008 deactivated)
# 17:03:43 INFO    opendrift.models.basemodel:2866: 2018-01-12 11:00:00 - step 276 of 1344 - 1008 active elements (1008 deactivated)
# 17:03:43 INFO    opendrift.models.basemodel:2866: 2018-01-12 12:00:00 - step 277 of 1344 - 1008 active elements (1008 deactivated)
# 17:03:44 INFO    opendrift.models.basemodel:2866: 2018-01-12 13:00:00 - step 278 of 1344 - 1008 active elements (1008 deactivated)
# 17:03:44 INFO    opendrift.models.basemodel:2866: 2018-01-12 14:00:00 - step 279 of 1344 - 1008 active elements (1008 deactivated)
# 17:03:44 INFO    opendrift.models.basemodel:2866: 2018-01-12 15:00:00 - step 280 of 1344 - 1008 active elements (1008 deactivated)
# 17:03:44 INFO    opendrift.models.basemodel:2866: 2018-01-12 16:00:00 - step 281 of 1344 - 1008 active elements (1008 deactivated)
# 17:03:45 INFO    opendrift.models.basemodel:2866: 2018-01-12 17:00:00 - step 282 of 1344 - 1008 active elements (1008 deactivated)
# 17:03:45 INFO    opendrift.models.basemodel:2866: 2018-01-12 18:00:00 - step 283 of 1344 - 1008 active elements (1008 deactivated)
# 17:03:45 INFO    opendrift.models.basemodel:2866: 2018-01-12 19:00:00 - step 284 of 1344 - 1008 active elements (1008 deactivated)
# 17:03:45 INFO    opendrift.models.basemodel:2866: 2018-01-12 20:00:00 - step 285 of 1344 - 1008 active elements (1008 deactivated)
# 17:03:45 INFO    opendrift.models.basemodel:2866: 2018-01-12 21:00:00 - step 286 of 1344 - 1008 active elements (1008 deactivated)
# 17:03:46 INFO    opendrift.models.basemodel:2866: 2018-01-12 22:00:00 - step 287 of 1344 - 1008 active elements (1008 deactivated)
# 17:03:46 INFO    opendrift.models.basemodel:2866: 2018-01-12 23:00:00 - step 288 of 1344 - 1008 active elements (1008 deactivated)
# 17:03:46 INFO    opendrift.models.basemodel:2866: 2018-01-13 00:00:00 - step 289 of 1344 - 1008 active elements (1008 deactivated)
# 17:03:46 INFO    opendrift.models.basemodel:2866: 2018-01-13 01:00:00 - step 290 of 1344 - 1008 active elements (1008 deactivated)
# 17:03:47 INFO    opendrift.models.basemodel:2866: 2018-01-13 02:00:00 - step 291 of 1344 - 1008 active elements (1008 deactivated)
# 17:03:47 INFO    opendrift.models.basemodel:2866: 2018-01-13 03:00:00 - step 292 of 1344 - 1008 active elements (1008 deactivated)
# 17:03:47 INFO    opendrift.models.basemodel:2866: 2018-01-13 04:00:00 - step 293 of 1344 - 1008 active elements (1008 deactivated)
# 17:03:47 INFO    opendrift.models.basemodel:2866: 2018-01-13 05:00:00 - step 294 of 1344 - 1008 active elements (1008 deactivated)
# 17:03:47 INFO    opendrift.models.basemodel:2866: 2018-01-13 06:00:00 - step 295 of 1344 - 1008 active elements (1008 deactivated)
# 17:03:48 INFO    opendrift.models.basemodel:2866: 2018-01-13 07:00:00 - step 296 of 1344 - 1008 active elements (1008 deactivated)
# 17:03:48 INFO    opendrift.models.basemodel:2866: 2018-01-13 08:00:00 - step 297 of 1344 - 1008 active elements (1008 deactivated)
# 17:03:48 INFO    opendrift.models.basemodel:2866: 2018-01-13 09:00:00 - step 298 of 1344 - 1008 active elements (1008 deactivated)
# 17:03:48 INFO    opendrift.models.basemodel:2866: 2018-01-13 10:00:00 - step 299 of 1344 - 1008 active elements (1008 deactivated)
# 17:03:49 INFO    opendrift.models.basemodel:2866: 2018-01-13 11:00:00 - step 300 of 1344 - 1008 active elements (1008 deactivated)
# 17:03:49 INFO    opendrift.models.basemodel:2866: 2018-01-13 12:00:00 - step 301 of 1344 - 1008 active elements (1008 deactivated)
# 17:03:49 INFO    opendrift.models.basemodel:2866: 2018-01-13 13:00:00 - step 302 of 1344 - 1008 active elements (1008 deactivated)
# 17:03:49 INFO    opendrift.models.basemodel:2866: 2018-01-13 14:00:00 - step 303 of 1344 - 1008 active elements (1008 deactivated)
# 17:03:49 INFO    opendrift.models.basemodel:2866: 2018-01-13 15:00:00 - step 304 of 1344 - 1008 active elements (1008 deactivated)
# 17:03:50 INFO    opendrift.models.basemodel:2866: 2018-01-13 16:00:00 - step 305 of 1344 - 996 active elements (1020 deactivated)
# 17:03:50 INFO    opendrift.models.basemodel:2866: 2018-01-13 17:00:00 - step 306 of 1344 - 996 active elements (1020 deactivated)
# 17:03:50 INFO    opendrift.models.basemodel:2866: 2018-01-13 18:00:00 - step 307 of 1344 - 996 active elements (1020 deactivated)
# 17:03:51 INFO    opendrift.models.basemodel:2866: 2018-01-13 19:00:00 - step 308 of 1344 - 996 active elements (1020 deactivated)
# 17:03:51 INFO    opendrift.models.basemodel:2866: 2018-01-13 20:00:00 - step 309 of 1344 - 984 active elements (1032 deactivated)
# 17:03:51 INFO    opendrift.models.basemodel:2866: 2018-01-13 21:00:00 - step 310 of 1344 - 984 active elements (1032 deactivated)
# 17:03:51 INFO    opendrift.models.basemodel:2866: 2018-01-13 22:00:00 - step 311 of 1344 - 984 active elements (1032 deactivated)
# 17:03:52 INFO    opendrift.models.basemodel:2866: 2018-01-13 23:00:00 - step 312 of 1344 - 984 active elements (1032 deactivated)
# 17:03:52 INFO    opendrift.models.basemodel:2866: 2018-01-14 00:00:00 - step 313 of 1344 - 984 active elements (1032 deactivated)
# 17:03:52 INFO    opendrift.models.basemodel:2866: 2018-01-14 01:00:00 - step 314 of 1344 - 984 active elements (1032 deactivated)
# 17:03:52 INFO    opendrift.models.basemodel:2866: 2018-01-14 02:00:00 - step 315 of 1344 - 984 active elements (1032 deactivated)
# 17:03:53 INFO    opendrift.models.basemodel:2866: 2018-01-14 03:00:00 - step 316 of 1344 - 984 active elements (1032 deactivated)
# 17:03:53 INFO    opendrift.models.basemodel:2866: 2018-01-14 04:00:00 - step 317 of 1344 - 984 active elements (1032 deactivated)
# 17:03:53 INFO    opendrift.models.basemodel:2866: 2018-01-14 05:00:00 - step 318 of 1344 - 972 active elements (1044 deactivated)
# 17:03:53 INFO    opendrift.models.basemodel:2866: 2018-01-14 06:00:00 - step 319 of 1344 - 948 active elements (1068 deactivated)
# 17:03:53 INFO    opendrift.models.basemodel:2866: 2018-01-14 07:00:00 - step 320 of 1344 - 948 active elements (1068 deactivated)
# 17:03:54 INFO    opendrift.models.basemodel:2866: 2018-01-14 08:00:00 - step 321 of 1344 - 936 active elements (1080 deactivated)
# 17:03:54 INFO    opendrift.models.basemodel:2866: 2018-01-14 09:00:00 - step 322 of 1344 - 936 active elements (1080 deactivated)
# 17:03:54 INFO    opendrift.models.basemodel:2866: 2018-01-14 10:00:00 - step 323 of 1344 - 936 active elements (1080 deactivated)
# 17:03:54 INFO    opendrift.models.basemodel:2866: 2018-01-14 11:00:00 - step 324 of 1344 - 936 active elements (1080 deactivated)
# 17:03:55 INFO    opendrift.models.basemodel:2866: 2018-01-14 12:00:00 - step 325 of 1344 - 936 active elements (1080 deactivated)
# 17:03:55 INFO    opendrift.models.basemodel:2866: 2018-01-14 13:00:00 - step 326 of 1344 - 936 active elements (1080 deactivated)
# 17:03:55 INFO    opendrift.models.basemodel:2866: 2018-01-14 14:00:00 - step 327 of 1344 - 936 active elements (1080 deactivated)
# 17:03:55 INFO    opendrift.models.basemodel:2866: 2018-01-14 15:00:00 - step 328 of 1344 - 936 active elements (1080 deactivated)
# 17:03:55 INFO    opendrift.models.basemodel:2866: 2018-01-14 16:00:00 - step 329 of 1344 - 936 active elements (1080 deactivated)
# 17:03:56 INFO    opendrift.models.basemodel:2866: 2018-01-14 17:00:00 - step 330 of 1344 - 936 active elements (1080 deactivated)
# 17:03:56 INFO    opendrift.models.basemodel:2866: 2018-01-14 18:00:00 - step 331 of 1344 - 936 active elements (1080 deactivated)
# 17:03:56 INFO    opendrift.models.basemodel:2866: 2018-01-14 19:00:00 - step 332 of 1344 - 936 active elements (1080 deactivated)
# 17:03:56 INFO    opendrift.models.basemodel:2866: 2018-01-14 20:00:00 - step 333 of 1344 - 936 active elements (1080 deactivated)
# 17:03:56 INFO    opendrift.models.basemodel:2866: 2018-01-14 21:00:00 - step 334 of 1344 - 936 active elements (1080 deactivated)
# 17:03:57 INFO    opendrift.models.basemodel:2866: 2018-01-14 22:00:00 - step 335 of 1344 - 936 active elements (1080 deactivated)
# 17:03:57 INFO    opendrift.models.basemodel:2866: 2018-01-14 23:00:00 - step 336 of 1344 - 936 active elements (1080 deactivated)
# 17:03:57 INFO    opendrift.models.basemodel:2866: 2018-01-15 00:00:00 - step 337 of 1344 - 936 active elements (1080 deactivated)
# 17:03:57 INFO    opendrift.models.basemodel:2866: 2018-01-15 01:00:00 - step 338 of 1344 - 936 active elements (1080 deactivated)
# 17:03:58 INFO    opendrift.models.basemodel:2866: 2018-01-15 02:00:00 - step 339 of 1344 - 936 active elements (1080 deactivated)
# 17:03:58 INFO    opendrift.models.basemodel:2866: 2018-01-15 03:00:00 - step 340 of 1344 - 936 active elements (1080 deactivated)
# 17:03:58 INFO    opendrift.models.basemodel:2866: 2018-01-15 04:00:00 - step 341 of 1344 - 936 active elements (1080 deactivated)
# 17:03:58 INFO    opendrift.models.basemodel:2866: 2018-01-15 05:00:00 - step 342 of 1344 - 936 active elements (1080 deactivated)
# 17:03:58 INFO    opendrift.models.basemodel:2866: 2018-01-15 06:00:00 - step 343 of 1344 - 936 active elements (1080 deactivated)
# 17:03:59 INFO    opendrift.models.basemodel:2866: 2018-01-15 07:00:00 - step 344 of 1344 - 936 active elements (1080 deactivated)
# 17:03:59 INFO    opendrift.models.basemodel:2866: 2018-01-15 08:00:00 - step 345 of 1344 - 936 active elements (1080 deactivated)
# 17:03:59 INFO    opendrift.models.basemodel:2866: 2018-01-15 09:00:00 - step 346 of 1344 - 936 active elements (1080 deactivated)
# 17:03:59 INFO    opendrift.models.basemodel:2866: 2018-01-15 10:00:00 - step 347 of 1344 - 936 active elements (1080 deactivated)
# 17:03:59 INFO    opendrift.models.basemodel:2866: 2018-01-15 11:00:00 - step 348 of 1344 - 936 active elements (1080 deactivated)
# 17:04:00 INFO    opendrift.models.basemodel:2866: 2018-01-15 12:00:00 - step 349 of 1344 - 936 active elements (1080 deactivated)
# 17:04:00 INFO    opendrift.models.basemodel:2866: 2018-01-15 13:00:00 - step 350 of 1344 - 936 active elements (1080 deactivated)
# 17:04:00 INFO    opendrift.models.basemodel:2866: 2018-01-15 14:00:00 - step 351 of 1344 - 936 active elements (1080 deactivated)
# ...
# 17:07:16 INFO    opendrift.models.basemodel:2866: 2018-02-20 22:00:00 - step 1223 of 1344 - 768 active elements (1248 deactivated)
# 17:07:17 INFO    opendrift.models.basemodel:2866: 2018-02-20 23:00:00 - step 1224 of 1344 - 768 active elements (1248 deactivated)
# 17:07:17 INFO    opendrift.models.basemodel:2866: 2018-02-21 00:00:00 - step 1225 of 1344 - 768 active elements (1248 deactivated)
# 17:07:17 INFO    opendrift.models.basemodel:2866: 2018-02-21 01:00:00 - step 1226 of 1344 - 768 active elements (1248 deactivated)
# 17:07:17 INFO    opendrift.models.basemodel:2866: 2018-02-21 02:00:00 - step 1227 of 1344 - 768 active elements (1248 deactivated)
# 17:07:18 INFO    opendrift.models.basemodel:2866: 2018-02-21 03:00:00 - step 1228 of 1344 - 768 active elements (1248 deactivated)
# 17:07:18 INFO    opendrift.models.basemodel:2866: 2018-02-21 04:00:00 - step 1229 of 1344 - 768 active elements (1248 deactivated)
# 17:07:18 INFO    opendrift.models.basemodel:2866: 2018-02-21 05:00:00 - step 1230 of 1344 - 768 active elements (1248 deactivated)
# 17:07:19 INFO    opendrift.models.basemodel:2866: 2018-02-21 06:00:00 - step 1231 of 1344 - 768 active elements (1248 deactivated)
# 17:07:19 INFO    opendrift.models.basemodel:2866: 2018-02-21 07:00:00 - step 1232 of 1344 - 768 active elements (1248 deactivated)
# 17:07:19 INFO    opendrift.models.basemodel:2866: 2018-02-21 08:00:00 - step 1233 of 1344 - 768 active elements (1248 deactivated)
# 17:07:19 INFO    opendrift.models.basemodel:2866: 2018-02-21 09:00:00 - step 1234 of 1344 - 768 active elements (1248 deactivated)
# 17:07:19 INFO    opendrift.models.basemodel:2866: 2018-02-21 10:00:00 - step 1235 of 1344 - 768 active elements (1248 deactivated)
# 17:07:20 INFO    opendrift.models.basemodel:2866: 2018-02-21 11:00:00 - step 1236 of 1344 - 768 active elements (1248 deactivated)
# 17:07:20 INFO    opendrift.models.basemodel:2866: 2018-02-21 12:00:00 - step 1237 of 1344 - 768 active elements (1248 deactivated)
# 17:07:20 INFO    opendrift.models.basemodel:2866: 2018-02-21 13:00:00 - step 1238 of 1344 - 768 active elements (1248 deactivated)
# 17:07:20 INFO    opendrift.models.basemodel:2866: 2018-02-21 14:00:00 - step 1239 of 1344 - 768 active elements (1248 deactivated)
# 17:07:21 INFO    opendrift.models.basemodel:2866: 2018-02-21 15:00:00 - step 1240 of 1344 - 768 active elements (1248 deactivated)
# 17:07:21 INFO    opendrift.models.basemodel:2866: 2018-02-21 16:00:00 - step 1241 of 1344 - 768 active elements (1248 deactivated)
# 17:07:21 INFO    opendrift.models.basemodel:2866: 2018-02-21 17:00:00 - step 1242 of 1344 - 768 active elements (1248 deactivated)
# 17:07:21 INFO    opendrift.models.basemodel:2866: 2018-02-21 18:00:00 - step 1243 of 1344 - 768 active elements (1248 deactivated)
# 17:07:22 INFO    opendrift.models.basemodel:2866: 2018-02-21 19:00:00 - step 1244 of 1344 - 768 active elements (1248 deactivated)
# 17:07:22 INFO    opendrift.models.basemodel:2866: 2018-02-21 20:00:00 - step 1245 of 1344 - 768 active elements (1248 deactivated)
# 17:07:22 INFO    opendrift.models.basemodel:2866: 2018-02-21 21:00:00 - step 1246 of 1344 - 768 active elements (1248 deactivated)
# 17:07:22 INFO    opendrift.models.basemodel:2866: 2018-02-21 22:00:00 - step 1247 of 1344 - 768 active elements (1248 deactivated)
# 17:07:23 INFO    opendrift.models.basemodel:2866: 2018-02-21 23:00:00 - step 1248 of 1344 - 756 active elements (1260 deactivated)
# 17:07:23 INFO    opendrift.models.basemodel:2866: 2018-02-22 00:00:00 - step 1249 of 1344 - 756 active elements (1260 deactivated)
# 17:07:23 INFO    opendrift.models.basemodel:2866: 2018-02-22 01:00:00 - step 1250 of 1344 - 756 active elements (1260 deactivated)
# 17:07:23 INFO    opendrift.models.basemodel:2866: 2018-02-22 02:00:00 - step 1251 of 1344 - 756 active elements (1260 deactivated)
# 17:07:24 INFO    opendrift.models.basemodel:2866: 2018-02-22 03:00:00 - step 1252 of 1344 - 756 active elements (1260 deactivated)
# 17:07:24 INFO    opendrift.models.basemodel:2866: 2018-02-22 04:00:00 - step 1253 of 1344 - 756 active elements (1260 deactivated)
# 17:07:24 INFO    opendrift.models.basemodel:2866: 2018-02-22 05:00:00 - step 1254 of 1344 - 756 active elements (1260 deactivated)
# 17:07:24 INFO    opendrift.models.basemodel:2866: 2018-02-22 06:00:00 - step 1255 of 1344 - 756 active elements (1260 deactivated)
# 17:07:25 INFO    opendrift.models.basemodel:2866: 2018-02-22 07:00:00 - step 1256 of 1344 - 756 active elements (1260 deactivated)
# 17:07:25 INFO    opendrift.models.basemodel:2866: 2018-02-22 08:00:00 - step 1257 of 1344 - 756 active elements (1260 deactivated)
# 17:07:25 INFO    opendrift.models.basemodel:2866: 2018-02-22 09:00:00 - step 1258 of 1344 - 756 active elements (1260 deactivated)
# 17:07:25 INFO    opendrift.models.basemodel:2866: 2018-02-22 10:00:00 - step 1259 of 1344 - 756 active elements (1260 deactivated)
# 17:07:25 INFO    opendrift.models.basemodel:2866: 2018-02-22 11:00:00 - step 1260 of 1344 - 744 active elements (1272 deactivated)
# 17:07:26 INFO    opendrift.models.basemodel:2866: 2018-02-22 12:00:00 - step 1261 of 1344 - 732 active elements (1284 deactivated)
# 17:07:26 INFO    opendrift.models.basemodel:2866: 2018-02-22 13:00:00 - step 1262 of 1344 - 732 active elements (1284 deactivated)
# 17:07:26 INFO    opendrift.models.basemodel:2866: 2018-02-22 14:00:00 - step 1263 of 1344 - 732 active elements (1284 deactivated)
# 17:07:26 INFO    opendrift.models.basemodel:2866: 2018-02-22 15:00:00 - step 1264 of 1344 - 732 active elements (1284 deactivated)
# 17:07:27 INFO    opendrift.models.basemodel:2866: 2018-02-22 16:00:00 - step 1265 of 1344 - 732 active elements (1284 deactivated)
# 17:07:27 INFO    opendrift.models.basemodel:2866: 2018-02-22 17:00:00 - step 1266 of 1344 - 732 active elements (1284 deactivated)
# 17:07:27 INFO    opendrift.models.basemodel:2866: 2018-02-22 18:00:00 - step 1267 of 1344 - 732 active elements (1284 deactivated)
# 17:07:27 INFO    opendrift.models.basemodel:2866: 2018-02-22 19:00:00 - step 1268 of 1344 - 732 active elements (1284 deactivated)
# 17:07:28 INFO    opendrift.models.basemodel:2866: 2018-02-22 20:00:00 - step 1269 of 1344 - 732 active elements (1284 deactivated)
# 17:07:28 INFO    opendrift.models.basemodel:2866: 2018-02-22 21:00:00 - step 1270 of 1344 - 732 active elements (1284 deactivated)
# 17:07:28 INFO    opendrift.models.basemodel:2866: 2018-02-22 22:00:00 - step 1271 of 1344 - 732 active elements (1284 deactivated)
# 17:07:28 INFO    opendrift.models.basemodel:2866: 2018-02-22 23:00:00 - step 1272 of 1344 - 732 active elements (1284 deactivated)
# 17:07:29 INFO    opendrift.models.basemodel:2866: 2018-02-23 00:00:00 - step 1273 of 1344 - 732 active elements (1284 deactivated)
# 17:07:29 INFO    opendrift.models.basemodel:2866: 2018-02-23 01:00:00 - step 1274 of 1344 - 732 active elements (1284 deactivated)
# 17:07:29 INFO    opendrift.models.basemodel:2866: 2018-02-23 02:00:00 - step 1275 of 1344 - 732 active elements (1284 deactivated)
# 17:07:29 INFO    opendrift.models.basemodel:2866: 2018-02-23 03:00:00 - step 1276 of 1344 - 732 active elements (1284 deactivated)
# 17:07:30 INFO    opendrift.models.basemodel:2866: 2018-02-23 04:00:00 - step 1277 of 1344 - 732 active elements (1284 deactivated)
# 17:07:30 INFO    opendrift.models.basemodel:2866: 2018-02-23 05:00:00 - step 1278 of 1344 - 732 active elements (1284 deactivated)
# 17:07:30 INFO    opendrift.models.basemodel:2866: 2018-02-23 06:00:00 - step 1279 of 1344 - 732 active elements (1284 deactivated)
# 17:07:30 INFO    opendrift.models.basemodel:2866: 2018-02-23 07:00:00 - step 1280 of 1344 - 732 active elements (1284 deactivated)
# 17:07:31 INFO    opendrift.models.basemodel:2866: 2018-02-23 08:00:00 - step 1281 of 1344 - 732 active elements (1284 deactivated)
# 17:07:31 INFO    opendrift.models.basemodel:2866: 2018-02-23 09:00:00 - step 1282 of 1344 - 732 active elements (1284 deactivated)
# 17:07:31 INFO    opendrift.models.basemodel:2866: 2018-02-23 10:00:00 - step 1283 of 1344 - 732 active elements (1284 deactivated)
# 17:07:31 INFO    opendrift.models.basemodel:2866: 2018-02-23 11:00:00 - step 1284 of 1344 - 732 active elements (1284 deactivated)
# 17:07:31 INFO    opendrift.models.basemodel:2866: 2018-02-23 12:00:00 - step 1285 of 1344 - 732 active elements (1284 deactivated)
# 17:07:32 INFO    opendrift.models.basemodel:2866: 2018-02-23 13:00:00 - step 1286 of 1344 - 732 active elements (1284 deactivated)
# 17:07:32 INFO    opendrift.models.basemodel:2866: 2018-02-23 14:00:00 - step 1287 of 1344 - 732 active elements (1284 deactivated)
# 17:07:32 INFO    opendrift.models.basemodel:2866: 2018-02-23 15:00:00 - step 1288 of 1344 - 732 active elements (1284 deactivated)
# 17:07:32 INFO    opendrift.models.basemodel:2866: 2018-02-23 16:00:00 - step 1289 of 1344 - 732 active elements (1284 deactivated)
# 17:07:33 INFO    opendrift.models.basemodel:2866: 2018-02-23 17:00:00 - step 1290 of 1344 - 732 active elements (1284 deactivated)
# 17:07:33 INFO    opendrift.models.basemodel:2866: 2018-02-23 18:00:00 - step 1291 of 1344 - 732 active elements (1284 deactivated)
# 17:07:33 INFO    opendrift.models.basemodel:2866: 2018-02-23 19:00:00 - step 1292 of 1344 - 732 active elements (1284 deactivated)
# 17:07:33 INFO    opendrift.models.basemodel:2866: 2018-02-23 20:00:00 - step 1293 of 1344 - 732 active elements (1284 deactivated)
# 17:07:34 INFO    opendrift.models.basemodel:2866: 2018-02-23 21:00:00 - step 1294 of 1344 - 732 active elements (1284 deactivated)
# 17:07:34 INFO    opendrift.models.basemodel:2866: 2018-02-23 22:00:00 - step 1295 of 1344 - 732 active elements (1284 deactivated)
# 17:07:34 INFO    opendrift.models.basemodel:2866: 2018-02-23 23:00:00 - step 1296 of 1344 - 732 active elements (1284 deactivated)
# 17:07:34 INFO    opendrift.models.basemodel:2866: 2018-02-24 00:00:00 - step 1297 of 1344 - 732 active elements (1284 deactivated)
# 17:07:34 INFO    opendrift.models.basemodel:2866: 2018-02-24 01:00:00 - step 1298 of 1344 - 732 active elements (1284 deactivated)
# 17:07:35 INFO    opendrift.models.basemodel:2866: 2018-02-24 02:00:00 - step 1299 of 1344 - 732 active elements (1284 deactivated)
# 17:07:35 INFO    opendrift.models.basemodel:2866: 2018-02-24 03:00:00 - step 1300 of 1344 - 732 active elements (1284 deactivated)
# 17:07:35 INFO    opendrift.models.basemodel:2866: 2018-02-24 04:00:00 - step 1301 of 1344 - 732 active elements (1284 deactivated)
# 17:07:35 INFO    opendrift.models.basemodel:2866: 2018-02-24 05:00:00 - step 1302 of 1344 - 732 active elements (1284 deactivated)
# 17:07:36 INFO    opendrift.models.basemodel:2866: 2018-02-24 06:00:00 - step 1303 of 1344 - 732 active elements (1284 deactivated)
# 17:07:36 INFO    opendrift.models.basemodel:2866: 2018-02-24 07:00:00 - step 1304 of 1344 - 732 active elements (1284 deactivated)
# 17:07:36 INFO    opendrift.models.basemodel:2866: 2018-02-24 08:00:00 - step 1305 of 1344 - 732 active elements (1284 deactivated)
# 17:07:36 INFO    opendrift.models.basemodel:2866: 2018-02-24 09:00:00 - step 1306 of 1344 - 732 active elements (1284 deactivated)
# 17:07:36 INFO    opendrift.models.basemodel:2866: 2018-02-24 10:00:00 - step 1307 of 1344 - 732 active elements (1284 deactivated)
# 17:07:37 INFO    opendrift.models.basemodel:2866: 2018-02-24 11:00:00 - step 1308 of 1344 - 732 active elements (1284 deactivated)
# 17:07:37 INFO    opendrift.models.basemodel:2866: 2018-02-24 12:00:00 - step 1309 of 1344 - 732 active elements (1284 deactivated)
# 17:07:37 INFO    opendrift.models.basemodel:2866: 2018-02-24 13:00:00 - step 1310 of 1344 - 732 active elements (1284 deactivated)
# 17:07:37 INFO    opendrift.models.basemodel:2866: 2018-02-24 14:00:00 - step 1311 of 1344 - 732 active elements (1284 deactivated)
# 17:07:38 INFO    opendrift.models.basemodel:2866: 2018-02-24 15:00:00 - step 1312 of 1344 - 732 active elements (1284 deactivated)
# 17:07:38 INFO    opendrift.models.basemodel:2866: 2018-02-24 16:00:00 - step 1313 of 1344 - 732 active elements (1284 deactivated)
# 17:07:38 INFO    opendrift.models.basemodel:2866: 2018-02-24 17:00:00 - step 1314 of 1344 - 732 active elements (1284 deactivated)
# 17:07:38 INFO    opendrift.models.basemodel:2866: 2018-02-24 18:00:00 - step 1315 of 1344 - 732 active elements (1284 deactivated)
# 17:07:39 INFO    opendrift.models.basemodel:2866: 2018-02-24 19:00:00 - step 1316 of 1344 - 732 active elements (1284 deactivated)
# 17:07:39 INFO    opendrift.models.basemodel:2866: 2018-02-24 20:00:00 - step 1317 of 1344 - 732 active elements (1284 deactivated)
# 17:07:39 INFO    opendrift.models.basemodel:2866: 2018-02-24 21:00:00 - step 1318 of 1344 - 732 active elements (1284 deactivated)
# 17:07:39 INFO    opendrift.models.basemodel:2866: 2018-02-24 22:00:00 - step 1319 of 1344 - 732 active elements (1284 deactivated)
# 17:07:39 INFO    opendrift.models.basemodel:2866: 2018-02-24 23:00:00 - step 1320 of 1344 - 732 active elements (1284 deactivated)
# 17:07:40 INFO    opendrift.models.basemodel:2866: 2018-02-25 00:00:00 - step 1321 of 1344 - 732 active elements (1284 deactivated)
# 17:07:40 INFO    opendrift.models.basemodel:2866: 2018-02-25 01:00:00 - step 1322 of 1344 - 732 active elements (1284 deactivated)
# 17:07:40 INFO    opendrift.models.basemodel:2866: 2018-02-25 02:00:00 - step 1323 of 1344 - 732 active elements (1284 deactivated)
# 17:07:40 INFO    opendrift.models.basemodel:2866: 2018-02-25 03:00:00 - step 1324 of 1344 - 732 active elements (1284 deactivated)
# 17:07:41 INFO    opendrift.models.basemodel:2866: 2018-02-25 04:00:00 - step 1325 of 1344 - 732 active elements (1284 deactivated)
# 17:07:41 INFO    opendrift.models.basemodel:2866: 2018-02-25 05:00:00 - step 1326 of 1344 - 732 active elements (1284 deactivated)
# 17:07:41 INFO    opendrift.models.basemodel:2866: 2018-02-25 06:00:00 - step 1327 of 1344 - 732 active elements (1284 deactivated)
# 17:07:41 INFO    opendrift.models.basemodel:2866: 2018-02-25 07:00:00 - step 1328 of 1344 - 732 active elements (1284 deactivated)
# 17:07:41 INFO    opendrift.models.basemodel:2866: 2018-02-25 08:00:00 - step 1329 of 1344 - 732 active elements (1284 deactivated)
# 17:07:42 INFO    opendrift.models.basemodel:2866: 2018-02-25 09:00:00 - step 1330 of 1344 - 732 active elements (1284 deactivated)
# 17:07:42 INFO    opendrift.models.basemodel:2866: 2018-02-25 10:00:00 - step 1331 of 1344 - 732 active elements (1284 deactivated)
# 17:07:42 INFO    opendrift.models.basemodel:2866: 2018-02-25 11:00:00 - step 1332 of 1344 - 720 active elements (1296 deactivated)
# 17:07:42 INFO    opendrift.models.basemodel:2866: 2018-02-25 12:00:00 - step 1333 of 1344 - 720 active elements (1296 deactivated)
# 17:07:43 INFO    opendrift.models.basemodel:2866: 2018-02-25 13:00:00 - step 1334 of 1344 - 720 active elements (1296 deactivated)
# 17:07:43 INFO    opendrift.models.basemodel:2866: 2018-02-25 14:00:00 - step 1335 of 1344 - 720 active elements (1296 deactivated)
# 17:07:43 INFO    opendrift.models.basemodel:2866: 2018-02-25 15:00:00 - step 1336 of 1344 - 720 active elements (1296 deactivated)
# 17:07:43 INFO    opendrift.models.basemodel:2866: 2018-02-25 16:00:00 - step 1337 of 1344 - 720 active elements (1296 deactivated)
# 17:07:44 INFO    opendrift.models.basemodel:2866: 2018-02-25 17:00:00 - step 1338 of 1344 - 720 active elements (1296 deactivated)
# 17:07:44 INFO    opendrift.models.basemodel:2866: 2018-02-25 18:00:00 - step 1339 of 1344 - 720 active elements (1296 deactivated)
# 17:07:44 INFO    opendrift.models.basemodel:2866: 2018-02-25 19:00:00 - step 1340 of 1344 - 720 active elements (1296 deactivated)
# 17:07:44 INFO    opendrift.models.basemodel:2866: 2018-02-25 20:00:00 - step 1341 of 1344 - 720 active elements (1296 deactivated)
# 17:07:44 INFO    opendrift.models.basemodel:2866: 2018-02-25 21:00:00 - step 1342 of 1344 - 720 active elements (1296 deactivated)
# 17:07:45 INFO    opendrift.models.basemodel:2866: 2018-02-25 22:00:00 - step 1343 of 1344 - 720 active elements (1296 deactivated)
# 17:07:45 INFO    opendrift.models.basemodel:2866: 2018-02-25 23:00:00 - step 1344 of 1344 - 720 active elements (1296 deactivated)

# %%
print(o)
o.plot()
# Out:
# ===========================
# --------------------
# Reader performance:
# --------------------
# roms native
#  0:04:10.7  total
#  0:00:00.1  preparing
#  0:04:00.3  reading
#  0:00:16.9  interpolation
#  0:00:00.0  interpolation_time
#  0:00:00.0  masking
#  0:00:10.1  rotating vectors
# --------------------
# global_landmask
#  0:00:01.3  total
#  0:00:00.1  preparing
#  0:00:01.1  reading
#  0:00:00.0  masking
# --------------------
# Performance:
#  5:21.8 total time
#     3.7 configuration
#     9.9 preparing main loop
#       8.2 making dynamical landmask
#       0.0 moving elements to ocean
#    4:32.5 readers
#         1.8 global_landmask
#         9.8 postprocessing
#  5:05.3 main loop
#      4:14.6 roms native
#       2.1 updating elements
#     2.8 cleaning up
# --------------------
# ===========================
# Model:	OceanDrift     (OpenDrift version 1.10.4)
# 	720 active Lagrangian3DArray particles  (1296 deactivated, 0 scheduled)
# -------------------
# Environment variables:
#   -----
#   ocean_vertical_diffusivity
#   sea_floor_depth_below_sea_level
#   upward_sea_water_velocity
#   x_sea_water_velocity
#   y_sea_water_velocity
#      1) roms native
#   -----
#   land_binary_mask
#      1) global_landmask
#   -----
# Readers not added for the following variables:
#   ocean_mixed_layer_thickness
#   sea_surface_wave_mean_period_from_variance_spectral_density_second_frequency_moment
#   sea_surface_wave_period_at_variance_spectral_density_maximum
#   sea_surface_wave_significant_height
#   sea_surface_wave_stokes_drift_x_velocity
#   sea_surface_wave_stokes_drift_y_velocity
#   surface_downward_x_stress
#   surface_downward_y_stress
#   turbulent_generic_length_scale
#   turbulent_kinetic_energy
#   x_wind
#   y_wind
#
# Time:
# 	Start: 2018-01-01 00:00:00
# 	Present: 2018-02-26 00:00:00
# 	Calculation steps: 1344 * 1:00:00 - total time: 56 days, 0:00:00
# 	Output steps: 1345 * 1:00:00
# ===========================
# Possible issue encountered when converting Shape #95 to GeoJSON: Shapefile format requires that polygons contain at least one exterior ring, but the Shape was entirely made up of interior holes (defined by counter-clockwise orientation in the shapefile format). The rings were still included but were encoded as GeoJSON exterior rings instead of holes.
# Possible issue encountered when converting Shape #95 to GeoJSON: Shapefile format requires that polygons contain at least one exterior ring, but the Shape was entirely made up of interior holes (defined by counter-clockwise orientation in the shapefile format). The rings were still included but were encoded as GeoJSON exterior rings instead of holes.
# Possible issue encountered when converting Shape #491 to GeoJSON: Shapefile format requires that polygons contain at least one exterior ring, but the Shape was entirely made up of interior holes (defined by counter-clockwise orientation in the shapefile format). The rings were still included but were encoded as GeoJSON exterior rings instead of holes.
# Possible issue encountered when converting Shape #491 to GeoJSON: Shapefile format requires that polygons contain at least one exterior ring, but the Shape was entirely made up of interior holes (defined by counter-clockwise orientation in the shapefile format). The rings were still included but were encoded as GeoJSON exterior rings instead of holes.
# (<GeoAxesSubplot: title={'center': 'OpenDrift - OceanDrift\n2018-01-01 00:00 to 2018-02-26 00:00 UTC (1345 steps)'}>,
#  <Figure size 1067.81x1100 with 1 Axes>)

# %%
o.history['lon'].shape
# Out:
# (2016, 1345)

# %%
times = [o.start_time + n * o.time_step_output
         for n in range(o.steps_output)]

# %%
times
# Out:
# [datetime.datetime(2018, 1, 1, 0, 0),
#  datetime.datetime(2018, 1, 1, 1, 0),
#  datetime.datetime(2018, 1, 1, 2, 0),
#  datetime.datetime(2018, 1, 1, 3, 0),
#  datetime.datetime(2018, 1, 1, 4, 0),
#  datetime.datetime(2018, 1, 1, 5, 0),
#  datetime.datetime(2018, 1, 1, 6, 0),
#  datetime.datetime(2018, 1, 1, 7, 0),
#  datetime.datetime(2018, 1, 1, 8, 0),
#  datetime.datetime(2018, 1, 1, 9, 0),
#  datetime.datetime(2018, 1, 1, 10, 0),
#  datetime.datetime(2018, 1, 1, 11, 0),
#  datetime.datetime(2018, 1, 1, 12, 0),
#  datetime.datetime(2018, 1, 1, 13, 0),
#  datetime.datetime(2018, 1, 1, 14, 0),
#  datetime.datetime(2018, 1, 1, 15, 0),
#  datetime.datetime(2018, 1, 1, 16, 0),
#  datetime.datetime(2018, 1, 1, 17, 0),
#  datetime.datetime(2018, 1, 1, 18, 0),
#  datetime.datetime(2018, 1, 1, 19, 0),
#  datetime.datetime(2018, 1, 1, 20, 0),
#  datetime.datetime(2018, 1, 1, 21, 0),
#  datetime.datetime(2018, 1, 1, 22, 0),
#  datetime.datetime(2018, 1, 1, 23, 0),
#  datetime.datetime(2018, 1, 2, 0, 0),
#  datetime.datetime(2018, 1, 2, 1, 0),
#  datetime.datetime(2018, 1, 2, 2, 0),
#  datetime.datetime(2018, 1, 2, 3, 0),
#  datetime.datetime(2018, 1, 2, 4, 0),
#  datetime.datetime(2018, 1, 2, 5, 0),
#  datetime.datetime(2018, 1, 2, 6, 0),
#  datetime.datetime(2018, 1, 2, 7, 0),
#  datetime.datetime(2018, 1, 2, 8, 0),
#  datetime.datetime(2018, 1, 2, 9, 0),
#  datetime.datetime(2018, 1, 2, 10, 0),
#  datetime.datetime(2018, 1, 2, 11, 0),
#  datetime.datetime(2018, 1, 2, 12, 0),
#  datetime.datetime(2018, 1, 2, 13, 0),
#  datetime.datetime(2018, 1, 2, 14, 0),
#  datetime.datetime(2018, 1, 2, 15, 0),
#  datetime.datetime(2018, 1, 2, 16, 0),
#  datetime.datetime(2018, 1, 2, 17, 0),
#  datetime.datetime(2018, 1, 2, 18, 0),
#  datetime.datetime(2018, 1, 2, 19, 0),
#  datetime.datetime(2018, 1, 2, 20, 0),
#  datetime.datetime(2018, 1, 2, 21, 0),
#  datetime.datetime(2018, 1, 2, 22, 0),
#  datetime.datetime(2018, 1, 2, 23, 0),
#  datetime.datetime(2018, 1, 3, 0, 0),
#  datetime.datetime(2018, 1, 3, 1, 0),
#  datetime.datetime(2018, 1, 3, 2, 0),
#  datetime.datetime(2018, 1, 3, 3, 0),
#  datetime.datetime(2018, 1, 3, 4, 0),
#  datetime.datetime(2018, 1, 3, 5, 0),
#  datetime.datetime(2018, 1, 3, 6, 0),
#  datetime.datetime(2018, 1, 3, 7, 0),
#  datetime.datetime(2018, 1, 3, 8, 0),
#  datetime.datetime(2018, 1, 3, 9, 0),
#  datetime.datetime(2018, 1, 3, 10, 0),
#  datetime.datetime(2018, 1, 3, 11, 0),
#  datetime.datetime(2018, 1, 3, 12, 0),
#  datetime.datetime(2018, 1, 3, 13, 0),
#  datetime.datetime(2018, 1, 3, 14, 0),
#  datetime.datetime(2018, 1, 3, 15, 0),
#  datetime.datetime(2018, 1, 3, 16, 0),
#  datetime.datetime(2018, 1, 3, 17, 0),
#  datetime.datetime(2018, 1, 3, 18, 0),
#  datetime.datetime(2018, 1, 3, 19, 0),
#  datetime.datetime(2018, 1, 3, 20, 0),
#  datetime.datetime(2018, 1, 3, 21, 0),
#  datetime.datetime(2018, 1, 3, 22, 0),
#  datetime.datetime(2018, 1, 3, 23, 0),
#  datetime.datetime(2018, 1, 4, 0, 0),
#  datetime.datetime(2018, 1, 4, 1, 0),
#  datetime.datetime(2018, 1, 4, 2, 0),
#  datetime.datetime(2018, 1, 4, 3, 0),
#  datetime.datetime(2018, 1, 4, 4, 0),
#  datetime.datetime(2018, 1, 4, 5, 0),
#  datetime.datetime(2018, 1, 4, 6, 0),
#  datetime.datetime(2018, 1, 4, 7, 0),
#  datetime.datetime(2018, 1, 4, 8, 0),
#  datetime.datetime(2018, 1, 4, 9, 0),
#  datetime.datetime(2018, 1, 4, 10, 0),
#  datetime.datetime(2018, 1, 4, 11, 0),
#  datetime.datetime(2018, 1, 4, 12, 0),
#  datetime.datetime(2018, 1, 4, 13, 0),
#  datetime.datetime(2018, 1, 4, 14, 0),
#  datetime.datetime(2018, 1, 4, 15, 0),
#  datetime.datetime(2018, 1, 4, 16, 0),
#  datetime.datetime(2018, 1, 4, 17, 0),
#  datetime.datetime(2018, 1, 4, 18, 0),
#  datetime.datetime(2018, 1, 4, 19, 0),
#  datetime.datetime(2018, 1, 4, 20, 0),
#  datetime.datetime(2018, 1, 4, 21, 0),
#  datetime.datetime(2018, 1, 4, 22, 0),
#  datetime.datetime(2018, 1, 4, 23, 0),
#  datetime.datetime(2018, 1, 5, 0, 0),
#  datetime.datetime(2018, 1, 5, 1, 0),
#  datetime.datetime(2018, 1, 5, 2, 0),
#  datetime.datetime(2018, 1, 5, 3, 0),
#  datetime.datetime(2018, 1, 5, 4, 0),
#  datetime.datetime(2018, 1, 5, 5, 0),
#  datetime.datetime(2018, 1, 5, 6, 0),
#  datetime.datetime(2018, 1, 5, 7, 0),
#  datetime.datetime(2018, 1, 5, 8, 0),
#  datetime.datetime(2018, 1, 5, 9, 0),
#  datetime.datetime(2018, 1, 5, 10, 0),
#  datetime.datetime(2018, 1, 5, 11, 0),
#  datetime.datetime(2018, 1, 5, 12, 0),
#  datetime.datetime(2018, 1, 5, 13, 0),
#  datetime.datetime(2018, 1, 5, 14, 0),
#  datetime.datetime(2018, 1, 5, 15, 0),
#  datetime.datetime(2018, 1, 5, 16, 0),
#  datetime.datetime(2018, 1, 5, 17, 0),
#  datetime.datetime(2018, 1, 5, 18, 0),
#  datetime.datetime(2018, 1, 5, 19, 0),
#  datetime.datetime(2018, 1, 5, 20, 0),
#  datetime.datetime(2018, 1, 5, 21, 0),
#  datetime.datetime(2018, 1, 5, 22, 0),
#  datetime.datetime(2018, 1, 5, 23, 0),
#  datetime.datetime(2018, 1, 6, 0, 0),
#  datetime.datetime(2018, 1, 6, 1, 0),
#  datetime.datetime(2018, 1, 6, 2, 0),
#  datetime.datetime(2018, 1, 6, 3, 0),
#  datetime.datetime(2018, 1, 6, 4, 0),
#  datetime.datetime(2018, 1, 6, 5, 0),
#  datetime.datetime(2018, 1, 6, 6, 0),
#  datetime.datetime(2018, 1, 6, 7, 0),
#  datetime.datetime(2018, 1, 6, 8, 0),
#  datetime.datetime(2018, 1, 6, 9, 0),
#  datetime.datetime(2018, 1, 6, 10, 0),
#  datetime.datetime(2018, 1, 6, 11, 0),
#  datetime.datetime(2018, 1, 6, 12, 0),
#  datetime.datetime(2018, 1, 6, 13, 0),
#  datetime.datetime(2018, 1, 6, 14, 0),
#  datetime.datetime(2018, 1, 6, 15, 0),
#  datetime.datetime(2018, 1, 6, 16, 0),
#  datetime.datetime(2018, 1, 6, 17, 0),
#  datetime.datetime(2018, 1, 6, 18, 0),
#  datetime.datetime(2018, 1, 6, 19, 0),
#  datetime.datetime(2018, 1, 6, 20, 0),
#  datetime.datetime(2018, 1, 6, 21, 0),
#  datetime.datetime(2018, 1, 6, 22, 0),
#  datetime.datetime(2018, 1, 6, 23, 0),
#  datetime.datetime(2018, 1, 7, 0, 0),
#  datetime.datetime(2018, 1, 7, 1, 0),
#  datetime.datetime(2018, 1, 7, 2, 0),
#  datetime.datetime(2018, 1, 7, 3, 0),
#  datetime.datetime(2018, 1, 7, 4, 0),
#  datetime.datetime(2018, 1, 7, 5, 0),
#  datetime.datetime(2018, 1, 7, 6, 0),
#  datetime.datetime(2018, 1, 7, 7, 0),
#  datetime.datetime(2018, 1, 7, 8, 0),
#  datetime.datetime(2018, 1, 7, 9, 0),
#  datetime.datetime(2018, 1, 7, 10, 0),
#  datetime.datetime(2018, 1, 7, 11, 0),
#  datetime.datetime(2018, 1, 7, 12, 0),
#  datetime.datetime(2018, 1, 7, 13, 0),
#  datetime.datetime(2018, 1, 7, 14, 0),
#  datetime.datetime(2018, 1, 7, 15, 0),
#  datetime.datetime(2018, 1, 7, 16, 0),
#  datetime.datetime(2018, 1, 7, 17, 0),
#  datetime.datetime(2018, 1, 7, 18, 0),
#  datetime.datetime(2018, 1, 7, 19, 0),
#  datetime.datetime(2018, 1, 7, 20, 0),
#  datetime.datetime(2018, 1, 7, 21, 0),
#  datetime.datetime(2018, 1, 7, 22, 0),
#  datetime.datetime(2018, 1, 7, 23, 0),
#  datetime.datetime(2018, 1, 8, 0, 0),
#  datetime.datetime(2018, 1, 8, 1, 0),
#  datetime.datetime(2018, 1, 8, 2, 0),
#  datetime.datetime(2018, 1, 8, 3, 0),
#  datetime.datetime(2018, 1, 8, 4, 0),
#  datetime.datetime(2018, 1, 8, 5, 0),
#  datetime.datetime(2018, 1, 8, 6, 0),
#  datetime.datetime(2018, 1, 8, 7, 0),
#  datetime.datetime(2018, 1, 8, 8, 0),
#  datetime.datetime(2018, 1, 8, 9, 0),
#  datetime.datetime(2018, 1, 8, 10, 0),
#  datetime.datetime(2018, 1, 8, 11, 0),
#  datetime.datetime(2018, 1, 8, 12, 0),
#  datetime.datetime(2018, 1, 8, 13, 0),
#  datetime.datetime(2018, 1, 8, 14, 0),
#  datetime.datetime(2018, 1, 8, 15, 0),
#  datetime.datetime(2018, 1, 8, 16, 0),
#  datetime.datetime(2018, 1, 8, 17, 0),
#  datetime.datetime(2018, 1, 8, 18, 0),
#  datetime.datetime(2018, 1, 8, 19, 0),
#  datetime.datetime(2018, 1, 8, 20, 0),
#  datetime.datetime(2018, 1, 8, 21, 0),
#  datetime.datetime(2018, 1, 8, 22, 0),
#  datetime.datetime(2018, 1, 8, 23, 0),
#  datetime.datetime(2018, 1, 9, 0, 0),
#  datetime.datetime(2018, 1, 9, 1, 0),
#  datetime.datetime(2018, 1, 9, 2, 0),
#  datetime.datetime(2018, 1, 9, 3, 0),
#  datetime.datetime(2018, 1, 9, 4, 0),
#  datetime.datetime(2018, 1, 9, 5, 0),
#  datetime.datetime(2018, 1, 9, 6, 0),
#  datetime.datetime(2018, 1, 9, 7, 0),
#  datetime.datetime(2018, 1, 9, 8, 0),
#  datetime.datetime(2018, 1, 9, 9, 0),
#  datetime.datetime(2018, 1, 9, 10, 0),
#  datetime.datetime(2018, 1, 9, 11, 0),
#  datetime.datetime(2018, 1, 9, 12, 0),
#  datetime.datetime(2018, 1, 9, 13, 0),
#  datetime.datetime(2018, 1, 9, 14, 0),
#  datetime.datetime(2018, 1, 9, 15, 0),
#  datetime.datetime(2018, 1, 9, 16, 0),
#  datetime.datetime(2018, 1, 9, 17, 0),
#  datetime.datetime(2018, 1, 9, 18, 0),
#  datetime.datetime(2018, 1, 9, 19, 0),
#  datetime.datetime(2018, 1, 9, 20, 0),
#  datetime.datetime(2018, 1, 9, 21, 0),
#  datetime.datetime(2018, 1, 9, 22, 0),
#  datetime.datetime(2018, 1, 9, 23, 0),
#  datetime.datetime(2018, 1, 10, 0, 0),
#  datetime.datetime(2018, 1, 10, 1, 0),
#  datetime.datetime(2018, 1, 10, 2, 0),
#  datetime.datetime(2018, 1, 10, 3, 0),
#  datetime.datetime(2018, 1, 10, 4, 0),
#  datetime.datetime(2018, 1, 10, 5, 0),
#  datetime.datetime(2018, 1, 10, 6, 0),
#  datetime.datetime(2018, 1, 10, 7, 0),
#  datetime.datetime(2018, 1, 10, 8, 0),
#  datetime.datetime(2018, 1, 10, 9, 0),
#  datetime.datetime(2018, 1, 10, 10, 0),
#  datetime.datetime(2018, 1, 10, 11, 0),
#  datetime.datetime(2018, 1, 10, 12, 0),
#  datetime.datetime(2018, 1, 10, 13, 0),
#  datetime.datetime(2018, 1, 10, 14, 0),
#  datetime.datetime(2018, 1, 10, 15, 0),
#  datetime.datetime(2018, 1, 10, 16, 0),
#  datetime.datetime(2018, 1, 10, 17, 0),
#  datetime.datetime(2018, 1, 10, 18, 0),
#  datetime.datetime(2018, 1, 10, 19, 0),
#  datetime.datetime(2018, 1, 10, 20, 0),
#  datetime.datetime(2018, 1, 10, 21, 0),
#  datetime.datetime(2018, 1, 10, 22, 0),
#  datetime.datetime(2018, 1, 10, 23, 0),
#  datetime.datetime(2018, 1, 11, 0, 0),
#  datetime.datetime(2018, 1, 11, 1, 0),
#  datetime.datetime(2018, 1, 11, 2, 0),
#  datetime.datetime(2018, 1, 11, 3, 0),
#  datetime.datetime(2018, 1, 11, 4, 0),
#  datetime.datetime(2018, 1, 11, 5, 0),
#  datetime.datetime(2018, 1, 11, 6, 0),
#  datetime.datetime(2018, 1, 11, 7, 0),
#  datetime.datetime(2018, 1, 11, 8, 0),
#  datetime.datetime(2018, 1, 11, 9, 0),
#  datetime.datetime(2018, 1, 11, 10, 0),
#  datetime.datetime(2018, 1, 11, 11, 0),
#  datetime.datetime(2018, 1, 11, 12, 0),
#  datetime.datetime(2018, 1, 11, 13, 0),
#  datetime.datetime(2018, 1, 11, 14, 0),
#  datetime.datetime(2018, 1, 11, 15, 0),
#  datetime.datetime(2018, 1, 11, 16, 0),
#  datetime.datetime(2018, 1, 11, 17, 0),
#  datetime.datetime(2018, 1, 11, 18, 0),
#  datetime.datetime(2018, 1, 11, 19, 0),
#  datetime.datetime(2018, 1, 11, 20, 0),
#  datetime.datetime(2018, 1, 11, 21, 0),
#  datetime.datetime(2018, 1, 11, 22, 0),
#  datetime.datetime(2018, 1, 11, 23, 0),
#  datetime.datetime(2018, 1, 12, 0, 0),
#  datetime.datetime(2018, 1, 12, 1, 0),
#  datetime.datetime(2018, 1, 12, 2, 0),
#  datetime.datetime(2018, 1, 12, 3, 0),
#  datetime.datetime(2018, 1, 12, 4, 0),
#  datetime.datetime(2018, 1, 12, 5, 0),
#  datetime.datetime(2018, 1, 12, 6, 0),
#  datetime.datetime(2018, 1, 12, 7, 0),
#  datetime.datetime(2018, 1, 12, 8, 0),
#  datetime.datetime(2018, 1, 12, 9, 0),
#  datetime.datetime(2018, 1, 12, 10, 0),
#  datetime.datetime(2018, 1, 12, 11, 0),
#  datetime.datetime(2018, 1, 12, 12, 0),
#  datetime.datetime(2018, 1, 12, 13, 0),
#  datetime.datetime(2018, 1, 12, 14, 0),
#  datetime.datetime(2018, 1, 12, 15, 0),
#  datetime.datetime(2018, 1, 12, 16, 0),
#  datetime.datetime(2018, 1, 12, 17, 0),
#  datetime.datetime(2018, 1, 12, 18, 0),
#  datetime.datetime(2018, 1, 12, 19, 0),
#  datetime.datetime(2018, 1, 12, 20, 0),
#  datetime.datetime(2018, 1, 12, 21, 0),
#  datetime.datetime(2018, 1, 12, 22, 0),
#  datetime.datetime(2018, 1, 12, 23, 0),
#  datetime.datetime(2018, 1, 13, 0, 0),
#  datetime.datetime(2018, 1, 13, 1, 0),
#  datetime.datetime(2018, 1, 13, 2, 0),
#  datetime.datetime(2018, 1, 13, 3, 0),
#  datetime.datetime(2018, 1, 13, 4, 0),
#  datetime.datetime(2018, 1, 13, 5, 0),
#  datetime.datetime(2018, 1, 13, 6, 0),
#  datetime.datetime(2018, 1, 13, 7, 0),
#  datetime.datetime(2018, 1, 13, 8, 0),
#  datetime.datetime(2018, 1, 13, 9, 0),
#  datetime.datetime(2018, 1, 13, 10, 0),
#  datetime.datetime(2018, 1, 13, 11, 0),
#  datetime.datetime(2018, 1, 13, 12, 0),
#  datetime.datetime(2018, 1, 13, 13, 0),
#  datetime.datetime(2018, 1, 13, 14, 0),
#  datetime.datetime(2018, 1, 13, 15, 0),
#  datetime.datetime(2018, 1, 13, 16, 0),
#  datetime.datetime(2018, 1, 13, 17, 0),
#  datetime.datetime(2018, 1, 13, 18, 0),
#  datetime.datetime(2018, 1, 13, 19, 0),
#  datetime.datetime(2018, 1, 13, 20, 0),
#  datetime.datetime(2018, 1, 13, 21, 0),
#  datetime.datetime(2018, 1, 13, 22, 0),
#  datetime.datetime(2018, 1, 13, 23, 0),
#  datetime.datetime(2018, 1, 14, 0, 0),
#  datetime.datetime(2018, 1, 14, 1, 0),
#  datetime.datetime(2018, 1, 14, 2, 0),
#  datetime.datetime(2018, 1, 14, 3, 0),
#  datetime.datetime(2018, 1, 14, 4, 0),
#  datetime.datetime(2018, 1, 14, 5, 0),
#  datetime.datetime(2018, 1, 14, 6, 0),
#  datetime.datetime(2018, 1, 14, 7, 0),
#  datetime.datetime(2018, 1, 14, 8, 0),
#  datetime.datetime(2018, 1, 14, 9, 0),
#  datetime.datetime(2018, 1, 14, 10, 0),
#  datetime.datetime(2018, 1, 14, 11, 0),
#  datetime.datetime(2018, 1, 14, 12, 0),
#  datetime.datetime(2018, 1, 14, 13, 0),
#  datetime.datetime(2018, 1, 14, 14, 0),
#  datetime.datetime(2018, 1, 14, 15, 0),
#  datetime.datetime(2018, 1, 14, 16, 0),
#  datetime.datetime(2018, 1, 14, 17, 0),
#  datetime.datetime(2018, 1, 14, 18, 0),
#  datetime.datetime(2018, 1, 14, 19, 0),
#  datetime.datetime(2018, 1, 14, 20, 0),
#  datetime.datetime(2018, 1, 14, 21, 0),
#  datetime.datetime(2018, 1, 14, 22, 0),
#  datetime.datetime(2018, 1, 14, 23, 0),
#  datetime.datetime(2018, 1, 15, 0, 0),
#  datetime.datetime(2018, 1, 15, 1, 0),
#  datetime.datetime(2018, 1, 15, 2, 0),
#  datetime.datetime(2018, 1, 15, 3, 0),
#  datetime.datetime(2018, 1, 15, 4, 0),
#  datetime.datetime(2018, 1, 15, 5, 0),
#  datetime.datetime(2018, 1, 15, 6, 0),
#  datetime.datetime(2018, 1, 15, 7, 0),
#  datetime.datetime(2018, 1, 15, 8, 0),
#  datetime.datetime(2018, 1, 15, 9, 0),
#  datetime.datetime(2018, 1, 15, 10, 0),
#  datetime.datetime(2018, 1, 15, 11, 0),
#  datetime.datetime(2018, 1, 15, 12, 0),
#  datetime.datetime(2018, 1, 15, 13, 0),
#  datetime.datetime(2018, 1, 15, 14, 0),
#  datetime.datetime(2018, 1, 15, 15, 0),
#  datetime.datetime(2018, 1, 15, 16, 0),
#  datetime.datetime(2018, 1, 15, 17, 0),
#  datetime.datetime(2018, 1, 15, 18, 0),
#  datetime.datetime(2018, 1, 15, 19, 0),
#  datetime.datetime(2018, 1, 15, 20, 0),
#  datetime.datetime(2018, 1, 15, 21, 0),
#  datetime.datetime(2018, 1, 15, 22, 0),
#  datetime.datetime(2018, 1, 15, 23, 0),
#  datetime.datetime(2018, 1, 16, 0, 0),
#  datetime.datetime(2018, 1, 16, 1, 0),
#  datetime.datetime(2018, 1, 16, 2, 0),
#  datetime.datetime(2018, 1, 16, 3, 0),
#  datetime.datetime(2018, 1, 16, 4, 0),
#  datetime.datetime(2018, 1, 16, 5, 0),
#  datetime.datetime(2018, 1, 16, 6, 0),
#  datetime.datetime(2018, 1, 16, 7, 0),
#  datetime.datetime(2018, 1, 16, 8, 0),
#  datetime.datetime(2018, 1, 16, 9, 0),
#  datetime.datetime(2018, 1, 16, 10, 0),
#  datetime.datetime(2018, 1, 16, 11, 0),
#  datetime.datetime(2018, 1, 16, 12, 0),
#  datetime.datetime(2018, 1, 16, 13, 0),
#  datetime.datetime(2018, 1, 16, 14, 0),
#  datetime.datetime(2018, 1, 16, 15, 0),
#  datetime.datetime(2018, 1, 16, 16, 0),
#  datetime.datetime(2018, 1, 16, 17, 0),
#  datetime.datetime(2018, 1, 16, 18, 0),
#  datetime.datetime(2018, 1, 16, 19, 0),
#  datetime.datetime(2018, 1, 16, 20, 0),
#  datetime.datetime(2018, 1, 16, 21, 0),
#  datetime.datetime(2018, 1, 16, 22, 0),
#  datetime.datetime(2018, 1, 16, 23, 0),
#  datetime.datetime(2018, 1, 17, 0, 0),
#  datetime.datetime(2018, 1, 17, 1, 0),
#  datetime.datetime(2018, 1, 17, 2, 0),
#  datetime.datetime(2018, 1, 17, 3, 0),
#  datetime.datetime(2018, 1, 17, 4, 0),
#  datetime.datetime(2018, 1, 17, 5, 0),
#  datetime.datetime(2018, 1, 17, 6, 0),
#  datetime.datetime(2018, 1, 17, 7, 0),
#  datetime.datetime(2018, 1, 17, 8, 0),
#  datetime.datetime(2018, 1, 17, 9, 0),
#  datetime.datetime(2018, 1, 17, 10, 0),
#  datetime.datetime(2018, 1, 17, 11, 0),
#  datetime.datetime(2018, 1, 17, 12, 0),
#  datetime.datetime(2018, 1, 17, 13, 0),
#  datetime.datetime(2018, 1, 17, 14, 0),
#  datetime.datetime(2018, 1, 17, 15, 0),
#  datetime.datetime(2018, 1, 17, 16, 0),
#  datetime.datetime(2018, 1, 17, 17, 0),
#  datetime.datetime(2018, 1, 17, 18, 0),
#  datetime.datetime(2018, 1, 17, 19, 0),
#  datetime.datetime(2018, 1, 17, 20, 0),
#  datetime.datetime(2018, 1, 17, 21, 0),
#  datetime.datetime(2018, 1, 17, 22, 0),
#  datetime.datetime(2018, 1, 17, 23, 0),
#  datetime.datetime(2018, 1, 18, 0, 0),
#  datetime.datetime(2018, 1, 18, 1, 0),
#  datetime.datetime(2018, 1, 18, 2, 0),
#  datetime.datetime(2018, 1, 18, 3, 0),
#  datetime.datetime(2018, 1, 18, 4, 0),
#  datetime.datetime(2018, 1, 18, 5, 0),
#  datetime.datetime(2018, 1, 18, 6, 0),
#  datetime.datetime(2018, 1, 18, 7, 0),
#  datetime.datetime(2018, 1, 18, 8, 0),
#  datetime.datetime(2018, 1, 18, 9, 0),
#  datetime.datetime(2018, 1, 18, 10, 0),
#  datetime.datetime(2018, 1, 18, 11, 0),
#  datetime.datetime(2018, 1, 18, 12, 0),
#  datetime.datetime(2018, 1, 18, 13, 0),
#  datetime.datetime(2018, 1, 18, 14, 0),
#  datetime.datetime(2018, 1, 18, 15, 0),
#  datetime.datetime(2018, 1, 18, 16, 0),
#  datetime.datetime(2018, 1, 18, 17, 0),
#  datetime.datetime(2018, 1, 18, 18, 0),
#  datetime.datetime(2018, 1, 18, 19, 0),
#  datetime.datetime(2018, 1, 18, 20, 0),
#  datetime.datetime(2018, 1, 18, 21, 0),
#  datetime.datetime(2018, 1, 18, 22, 0),
#  datetime.datetime(2018, 1, 18, 23, 0),
#  datetime.datetime(2018, 1, 19, 0, 0),
#  datetime.datetime(2018, 1, 19, 1, 0),
#  datetime.datetime(2018, 1, 19, 2, 0),
#  datetime.datetime(2018, 1, 19, 3, 0),
#  datetime.datetime(2018, 1, 19, 4, 0),
#  datetime.datetime(2018, 1, 19, 5, 0),
#  datetime.datetime(2018, 1, 19, 6, 0),
#  datetime.datetime(2018, 1, 19, 7, 0),
#  datetime.datetime(2018, 1, 19, 8, 0),
#  datetime.datetime(2018, 1, 19, 9, 0),
#  datetime.datetime(2018, 1, 19, 10, 0),
#  datetime.datetime(2018, 1, 19, 11, 0),
#  datetime.datetime(2018, 1, 19, 12, 0),
#  datetime.datetime(2018, 1, 19, 13, 0),
#  datetime.datetime(2018, 1, 19, 14, 0),
#  datetime.datetime(2018, 1, 19, 15, 0),
#  datetime.datetime(2018, 1, 19, 16, 0),
#  datetime.datetime(2018, 1, 19, 17, 0),
#  datetime.datetime(2018, 1, 19, 18, 0),
#  datetime.datetime(2018, 1, 19, 19, 0),
#  datetime.datetime(2018, 1, 19, 20, 0),
#  datetime.datetime(2018, 1, 19, 21, 0),
#  datetime.datetime(2018, 1, 19, 22, 0),
#  datetime.datetime(2018, 1, 19, 23, 0),
#  datetime.datetime(2018, 1, 20, 0, 0),
#  datetime.datetime(2018, 1, 20, 1, 0),
#  datetime.datetime(2018, 1, 20, 2, 0),
#  datetime.datetime(2018, 1, 20, 3, 0),
#  datetime.datetime(2018, 1, 20, 4, 0),
#  datetime.datetime(2018, 1, 20, 5, 0),
#  datetime.datetime(2018, 1, 20, 6, 0),
#  datetime.datetime(2018, 1, 20, 7, 0),
#  datetime.datetime(2018, 1, 20, 8, 0),
#  datetime.datetime(2018, 1, 20, 9, 0),
#  datetime.datetime(2018, 1, 20, 10, 0),
#  datetime.datetime(2018, 1, 20, 11, 0),
#  datetime.datetime(2018, 1, 20, 12, 0),
#  datetime.datetime(2018, 1, 20, 13, 0),
#  datetime.datetime(2018, 1, 20, 14, 0),
#  datetime.datetime(2018, 1, 20, 15, 0),
#  datetime.datetime(2018, 1, 20, 16, 0),
#  datetime.datetime(2018, 1, 20, 17, 0),
#  datetime.datetime(2018, 1, 20, 18, 0),
#  datetime.datetime(2018, 1, 20, 19, 0),
#  datetime.datetime(2018, 1, 20, 20, 0),
#  datetime.datetime(2018, 1, 20, 21, 0),
#  datetime.datetime(2018, 1, 20, 22, 0),
#  datetime.datetime(2018, 1, 20, 23, 0),
#  datetime.datetime(2018, 1, 21, 0, 0),
#  datetime.datetime(2018, 1, 21, 1, 0),
#  datetime.datetime(2018, 1, 21, 2, 0),
#  datetime.datetime(2018, 1, 21, 3, 0),
#  datetime.datetime(2018, 1, 21, 4, 0),
#  datetime.datetime(2018, 1, 21, 5, 0),
#  datetime.datetime(2018, 1, 21, 6, 0),
#  datetime.datetime(2018, 1, 21, 7, 0),
#  datetime.datetime(2018, 1, 21, 8, 0),
#  datetime.datetime(2018, 1, 21, 9, 0),
#  datetime.datetime(2018, 1, 21, 10, 0),
#  datetime.datetime(2018, 1, 21, 11, 0),
#  datetime.datetime(2018, 1, 21, 12, 0),
#  datetime.datetime(2018, 1, 21, 13, 0),
#  datetime.datetime(2018, 1, 21, 14, 0),
#  datetime.datetime(2018, 1, 21, 15, 0),
#  datetime.datetime(2018, 1, 21, 16, 0),
#  datetime.datetime(2018, 1, 21, 17, 0),
#  datetime.datetime(2018, 1, 21, 18, 0),
#  datetime.datetime(2018, 1, 21, 19, 0),
#  datetime.datetime(2018, 1, 21, 20, 0),
#  datetime.datetime(2018, 1, 21, 21, 0),
#  datetime.datetime(2018, 1, 21, 22, 0),
#  datetime.datetime(2018, 1, 21, 23, 0),
#  datetime.datetime(2018, 1, 22, 0, 0),
#  datetime.datetime(2018, 1, 22, 1, 0),
#  datetime.datetime(2018, 1, 22, 2, 0),
#  datetime.datetime(2018, 1, 22, 3, 0),
#  datetime.datetime(2018, 1, 22, 4, 0),
#  datetime.datetime(2018, 1, 22, 5, 0),
#  datetime.datetime(2018, 1, 22, 6, 0),
#  datetime.datetime(2018, 1, 22, 7, 0),
#  datetime.datetime(2018, 1, 22, 8, 0),
#  datetime.datetime(2018, 1, 22, 9, 0),
#  datetime.datetime(2018, 1, 22, 10, 0),
#  datetime.datetime(2018, 1, 22, 11, 0),
#  datetime.datetime(2018, 1, 22, 12, 0),
#  datetime.datetime(2018, 1, 22, 13, 0),
#  datetime.datetime(2018, 1, 22, 14, 0),
#  datetime.datetime(2018, 1, 22, 15, 0),
#  datetime.datetime(2018, 1, 22, 16, 0),
#  datetime.datetime(2018, 1, 22, 17, 0),
#  datetime.datetime(2018, 1, 22, 18, 0),
#  datetime.datetime(2018, 1, 22, 19, 0),
#  datetime.datetime(2018, 1, 22, 20, 0),
#  datetime.datetime(2018, 1, 22, 21, 0),
#  datetime.datetime(2018, 1, 22, 22, 0),
#  datetime.datetime(2018, 1, 22, 23, 0),
#  datetime.datetime(2018, 1, 23, 0, 0),
#  datetime.datetime(2018, 1, 23, 1, 0),
#  datetime.datetime(2018, 1, 23, 2, 0),
#  datetime.datetime(2018, 1, 23, 3, 0),
#  datetime.datetime(2018, 1, 23, 4, 0),
#  datetime.datetime(2018, 1, 23, 5, 0),
#  datetime.datetime(2018, 1, 23, 6, 0),
#  datetime.datetime(2018, 1, 23, 7, 0),
#  datetime.datetime(2018, 1, 23, 8, 0),
#  datetime.datetime(2018, 1, 23, 9, 0),
#  datetime.datetime(2018, 1, 23, 10, 0),
#  datetime.datetime(2018, 1, 23, 11, 0),
#  datetime.datetime(2018, 1, 23, 12, 0),
#  datetime.datetime(2018, 1, 23, 13, 0),
#  datetime.datetime(2018, 1, 23, 14, 0),
#  datetime.datetime(2018, 1, 23, 15, 0),
#  datetime.datetime(2018, 1, 23, 16, 0),
#  datetime.datetime(2018, 1, 23, 17, 0),
#  datetime.datetime(2018, 1, 23, 18, 0),
#  datetime.datetime(2018, 1, 23, 19, 0),
#  datetime.datetime(2018, 1, 23, 20, 0),
#  datetime.datetime(2018, 1, 23, 21, 0),
#  datetime.datetime(2018, 1, 23, 22, 0),
#  datetime.datetime(2018, 1, 23, 23, 0),
#  datetime.datetime(2018, 1, 24, 0, 0),
#  datetime.datetime(2018, 1, 24, 1, 0),
#  datetime.datetime(2018, 1, 24, 2, 0),
#  datetime.datetime(2018, 1, 24, 3, 0),
#  datetime.datetime(2018, 1, 24, 4, 0),
#  datetime.datetime(2018, 1, 24, 5, 0),
#  datetime.datetime(2018, 1, 24, 6, 0),
#  datetime.datetime(2018, 1, 24, 7, 0),
#  datetime.datetime(2018, 1, 24, 8, 0),
#  datetime.datetime(2018, 1, 24, 9, 0),
#  datetime.datetime(2018, 1, 24, 10, 0),
#  datetime.datetime(2018, 1, 24, 11, 0),
#  datetime.datetime(2018, 1, 24, 12, 0),
#  datetime.datetime(2018, 1, 24, 13, 0),
#  datetime.datetime(2018, 1, 24, 14, 0),
#  datetime.datetime(2018, 1, 24, 15, 0),
#  datetime.datetime(2018, 1, 24, 16, 0),
#  datetime.datetime(2018, 1, 24, 17, 0),
#  datetime.datetime(2018, 1, 24, 18, 0),
#  datetime.datetime(2018, 1, 24, 19, 0),
#  datetime.datetime(2018, 1, 24, 20, 0),
#  datetime.datetime(2018, 1, 24, 21, 0),
#  datetime.datetime(2018, 1, 24, 22, 0),
#  datetime.datetime(2018, 1, 24, 23, 0),
#  datetime.datetime(2018, 1, 25, 0, 0),
#  datetime.datetime(2018, 1, 25, 1, 0),
#  datetime.datetime(2018, 1, 25, 2, 0),
#  datetime.datetime(2018, 1, 25, 3, 0),
#  datetime.datetime(2018, 1, 25, 4, 0),
#  datetime.datetime(2018, 1, 25, 5, 0),
#  datetime.datetime(2018, 1, 25, 6, 0),
#  datetime.datetime(2018, 1, 25, 7, 0),
#  datetime.datetime(2018, 1, 25, 8, 0),
#  datetime.datetime(2018, 1, 25, 9, 0),
#  datetime.datetime(2018, 1, 25, 10, 0),
#  datetime.datetime(2018, 1, 25, 11, 0),
#  datetime.datetime(2018, 1, 25, 12, 0),
#  datetime.datetime(2018, 1, 25, 13, 0),
#  datetime.datetime(2018, 1, 25, 14, 0),
#  datetime.datetime(2018, 1, 25, 15, 0),
#  datetime.datetime(2018, 1, 25, 16, 0),
#  datetime.datetime(2018, 1, 25, 17, 0),
#  datetime.datetime(2018, 1, 25, 18, 0),
#  datetime.datetime(2018, 1, 25, 19, 0),
#  datetime.datetime(2018, 1, 25, 20, 0),
#  datetime.datetime(2018, 1, 25, 21, 0),
#  datetime.datetime(2018, 1, 25, 22, 0),
#  datetime.datetime(2018, 1, 25, 23, 0),
#  datetime.datetime(2018, 1, 26, 0, 0),
#  datetime.datetime(2018, 1, 26, 1, 0),
#  datetime.datetime(2018, 1, 26, 2, 0),
#  datetime.datetime(2018, 1, 26, 3, 0),
#  datetime.datetime(2018, 1, 26, 4, 0),
#  datetime.datetime(2018, 1, 26, 5, 0),
#  datetime.datetime(2018, 1, 26, 6, 0),
#  datetime.datetime(2018, 1, 26, 7, 0),
#  datetime.datetime(2018, 1, 26, 8, 0),
#  datetime.datetime(2018, 1, 26, 9, 0),
#  datetime.datetime(2018, 1, 26, 10, 0),
#  datetime.datetime(2018, 1, 26, 11, 0),
#  datetime.datetime(2018, 1, 26, 12, 0),
#  datetime.datetime(2018, 1, 26, 13, 0),
#  datetime.datetime(2018, 1, 26, 14, 0),
#  datetime.datetime(2018, 1, 26, 15, 0),
#  datetime.datetime(2018, 1, 26, 16, 0),
#  datetime.datetime(2018, 1, 26, 17, 0),
#  datetime.datetime(2018, 1, 26, 18, 0),
#  datetime.datetime(2018, 1, 26, 19, 0),
#  datetime.datetime(2018, 1, 26, 20, 0),
#  datetime.datetime(2018, 1, 26, 21, 0),
#  datetime.datetime(2018, 1, 26, 22, 0),
#  datetime.datetime(2018, 1, 26, 23, 0),
#  datetime.datetime(2018, 1, 27, 0, 0),
#  datetime.datetime(2018, 1, 27, 1, 0),
#  datetime.datetime(2018, 1, 27, 2, 0),
#  datetime.datetime(2018, 1, 27, 3, 0),
#  datetime.datetime(2018, 1, 27, 4, 0),
#  datetime.datetime(2018, 1, 27, 5, 0),
#  datetime.datetime(2018, 1, 27, 6, 0),
#  datetime.datetime(2018, 1, 27, 7, 0),
#  datetime.datetime(2018, 1, 27, 8, 0),
#  datetime.datetime(2018, 1, 27, 9, 0),
#  datetime.datetime(2018, 1, 27, 10, 0),
#  datetime.datetime(2018, 1, 27, 11, 0),
#  datetime.datetime(2018, 1, 27, 12, 0),
#  datetime.datetime(2018, 1, 27, 13, 0),
#  datetime.datetime(2018, 1, 27, 14, 0),
#  datetime.datetime(2018, 1, 27, 15, 0),
#  datetime.datetime(2018, 1, 27, 16, 0),
#  datetime.datetime(2018, 1, 27, 17, 0),
#  datetime.datetime(2018, 1, 27, 18, 0),
#  datetime.datetime(2018, 1, 27, 19, 0),
#  datetime.datetime(2018, 1, 27, 20, 0),
#  datetime.datetime(2018, 1, 27, 21, 0),
#  datetime.datetime(2018, 1, 27, 22, 0),
#  datetime.datetime(2018, 1, 27, 23, 0),
#  datetime.datetime(2018, 1, 28, 0, 0),
#  datetime.datetime(2018, 1, 28, 1, 0),
#  datetime.datetime(2018, 1, 28, 2, 0),
#  datetime.datetime(2018, 1, 28, 3, 0),
#  datetime.datetime(2018, 1, 28, 4, 0),
#  datetime.datetime(2018, 1, 28, 5, 0),
#  datetime.datetime(2018, 1, 28, 6, 0),
#  datetime.datetime(2018, 1, 28, 7, 0),
#  datetime.datetime(2018, 1, 28, 8, 0),
#  datetime.datetime(2018, 1, 28, 9, 0),
#  datetime.datetime(2018, 1, 28, 10, 0),
#  datetime.datetime(2018, 1, 28, 11, 0),
#  datetime.datetime(2018, 1, 28, 12, 0),
#  datetime.datetime(2018, 1, 28, 13, 0),
#  datetime.datetime(2018, 1, 28, 14, 0),
#  datetime.datetime(2018, 1, 28, 15, 0),
#  datetime.datetime(2018, 1, 28, 16, 0),
#  datetime.datetime(2018, 1, 28, 17, 0),
#  datetime.datetime(2018, 1, 28, 18, 0),
#  datetime.datetime(2018, 1, 28, 19, 0),
#  datetime.datetime(2018, 1, 28, 20, 0),
#  datetime.datetime(2018, 1, 28, 21, 0),
#  datetime.datetime(2018, 1, 28, 22, 0),
#  datetime.datetime(2018, 1, 28, 23, 0),
#  datetime.datetime(2018, 1, 29, 0, 0),
#  datetime.datetime(2018, 1, 29, 1, 0),
#  datetime.datetime(2018, 1, 29, 2, 0),
#  datetime.datetime(2018, 1, 29, 3, 0),
#  datetime.datetime(2018, 1, 29, 4, 0),
#  datetime.datetime(2018, 1, 29, 5, 0),
#  datetime.datetime(2018, 1, 29, 6, 0),
#  datetime.datetime(2018, 1, 29, 7, 0),
#  datetime.datetime(2018, 1, 29, 8, 0),
#  datetime.datetime(2018, 1, 29, 9, 0),
#  datetime.datetime(2018, 1, 29, 10, 0),
#  datetime.datetime(2018, 1, 29, 11, 0),
#  datetime.datetime(2018, 1, 29, 12, 0),
#  datetime.datetime(2018, 1, 29, 13, 0),
#  datetime.datetime(2018, 1, 29, 14, 0),
#  datetime.datetime(2018, 1, 29, 15, 0),
#  datetime.datetime(2018, 1, 29, 16, 0),
#  datetime.datetime(2018, 1, 29, 17, 0),
#  datetime.datetime(2018, 1, 29, 18, 0),
#  datetime.datetime(2018, 1, 29, 19, 0),
#  datetime.datetime(2018, 1, 29, 20, 0),
#  datetime.datetime(2018, 1, 29, 21, 0),
#  datetime.datetime(2018, 1, 29, 22, 0),
#  datetime.datetime(2018, 1, 29, 23, 0),
#  datetime.datetime(2018, 1, 30, 0, 0),
#  datetime.datetime(2018, 1, 30, 1, 0),
#  datetime.datetime(2018, 1, 30, 2, 0),
#  datetime.datetime(2018, 1, 30, 3, 0),
#  datetime.datetime(2018, 1, 30, 4, 0),
#  datetime.datetime(2018, 1, 30, 5, 0),
#  datetime.datetime(2018, 1, 30, 6, 0),
#  datetime.datetime(2018, 1, 30, 7, 0),
#  datetime.datetime(2018, 1, 30, 8, 0),
#  datetime.datetime(2018, 1, 30, 9, 0),
#  datetime.datetime(2018, 1, 30, 10, 0),
#  datetime.datetime(2018, 1, 30, 11, 0),
#  datetime.datetime(2018, 1, 30, 12, 0),
#  datetime.datetime(2018, 1, 30, 13, 0),
#  datetime.datetime(2018, 1, 30, 14, 0),
#  datetime.datetime(2018, 1, 30, 15, 0),
#  datetime.datetime(2018, 1, 30, 16, 0),
#  datetime.datetime(2018, 1, 30, 17, 0),
#  datetime.datetime(2018, 1, 30, 18, 0),
#  datetime.datetime(2018, 1, 30, 19, 0),
#  datetime.datetime(2018, 1, 30, 20, 0),
#  datetime.datetime(2018, 1, 30, 21, 0),
#  datetime.datetime(2018, 1, 30, 22, 0),
#  datetime.datetime(2018, 1, 30, 23, 0),
#  datetime.datetime(2018, 1, 31, 0, 0),
#  datetime.datetime(2018, 1, 31, 1, 0),
#  datetime.datetime(2018, 1, 31, 2, 0),
#  datetime.datetime(2018, 1, 31, 3, 0),
#  datetime.datetime(2018, 1, 31, 4, 0),
#  datetime.datetime(2018, 1, 31, 5, 0),
#  datetime.datetime(2018, 1, 31, 6, 0),
#  datetime.datetime(2018, 1, 31, 7, 0),
#  datetime.datetime(2018, 1, 31, 8, 0),
#  datetime.datetime(2018, 1, 31, 9, 0),
#  datetime.datetime(2018, 1, 31, 10, 0),
#  datetime.datetime(2018, 1, 31, 11, 0),
#  datetime.datetime(2018, 1, 31, 12, 0),
#  datetime.datetime(2018, 1, 31, 13, 0),
#  datetime.datetime(2018, 1, 31, 14, 0),
#  datetime.datetime(2018, 1, 31, 15, 0),
#  datetime.datetime(2018, 1, 31, 16, 0),
#  datetime.datetime(2018, 1, 31, 17, 0),
#  datetime.datetime(2018, 1, 31, 18, 0),
#  datetime.datetime(2018, 1, 31, 19, 0),
#  datetime.datetime(2018, 1, 31, 20, 0),
#  datetime.datetime(2018, 1, 31, 21, 0),
#  datetime.datetime(2018, 1, 31, 22, 0),
#  datetime.datetime(2018, 1, 31, 23, 0),
#  datetime.datetime(2018, 2, 1, 0, 0),
#  datetime.datetime(2018, 2, 1, 1, 0),
#  datetime.datetime(2018, 2, 1, 2, 0),
#  datetime.datetime(2018, 2, 1, 3, 0),
#  datetime.datetime(2018, 2, 1, 4, 0),
#  datetime.datetime(2018, 2, 1, 5, 0),
#  datetime.datetime(2018, 2, 1, 6, 0),
#  datetime.datetime(2018, 2, 1, 7, 0),
#  datetime.datetime(2018, 2, 1, 8, 0),
#  datetime.datetime(2018, 2, 1, 9, 0),
#  datetime.datetime(2018, 2, 1, 10, 0),
#  datetime.datetime(2018, 2, 1, 11, 0),
#  datetime.datetime(2018, 2, 1, 12, 0),
#  datetime.datetime(2018, 2, 1, 13, 0),
#  datetime.datetime(2018, 2, 1, 14, 0),
#  datetime.datetime(2018, 2, 1, 15, 0),
#  datetime.datetime(2018, 2, 1, 16, 0),
#  datetime.datetime(2018, 2, 1, 17, 0),
#  datetime.datetime(2018, 2, 1, 18, 0),
#  datetime.datetime(2018, 2, 1, 19, 0),
#  datetime.datetime(2018, 2, 1, 20, 0),
#  datetime.datetime(2018, 2, 1, 21, 0),
#  datetime.datetime(2018, 2, 1, 22, 0),
#  datetime.datetime(2018, 2, 1, 23, 0),
#  datetime.datetime(2018, 2, 2, 0, 0),
#  datetime.datetime(2018, 2, 2, 1, 0),
#  datetime.datetime(2018, 2, 2, 2, 0),
#  datetime.datetime(2018, 2, 2, 3, 0),
#  datetime.datetime(2018, 2, 2, 4, 0),
#  datetime.datetime(2018, 2, 2, 5, 0),
#  datetime.datetime(2018, 2, 2, 6, 0),
#  datetime.datetime(2018, 2, 2, 7, 0),
#  datetime.datetime(2018, 2, 2, 8, 0),
#  datetime.datetime(2018, 2, 2, 9, 0),
#  datetime.datetime(2018, 2, 2, 10, 0),
#  datetime.datetime(2018, 2, 2, 11, 0),
#  datetime.datetime(2018, 2, 2, 12, 0),
#  datetime.datetime(2018, 2, 2, 13, 0),
#  datetime.datetime(2018, 2, 2, 14, 0),
#  datetime.datetime(2018, 2, 2, 15, 0),
#  datetime.datetime(2018, 2, 2, 16, 0),
#  datetime.datetime(2018, 2, 2, 17, 0),
#  datetime.datetime(2018, 2, 2, 18, 0),
#  datetime.datetime(2018, 2, 2, 19, 0),
#  datetime.datetime(2018, 2, 2, 20, 0),
#  datetime.datetime(2018, 2, 2, 21, 0),
#  datetime.datetime(2018, 2, 2, 22, 0),
#  datetime.datetime(2018, 2, 2, 23, 0),
#  datetime.datetime(2018, 2, 3, 0, 0),
#  datetime.datetime(2018, 2, 3, 1, 0),
#  datetime.datetime(2018, 2, 3, 2, 0),
#  datetime.datetime(2018, 2, 3, 3, 0),
#  datetime.datetime(2018, 2, 3, 4, 0),
#  datetime.datetime(2018, 2, 3, 5, 0),
#  datetime.datetime(2018, 2, 3, 6, 0),
#  datetime.datetime(2018, 2, 3, 7, 0),
#  datetime.datetime(2018, 2, 3, 8, 0),
#  datetime.datetime(2018, 2, 3, 9, 0),
#  datetime.datetime(2018, 2, 3, 10, 0),
#  datetime.datetime(2018, 2, 3, 11, 0),
#  datetime.datetime(2018, 2, 3, 12, 0),
#  datetime.datetime(2018, 2, 3, 13, 0),
#  datetime.datetime(2018, 2, 3, 14, 0),
#  datetime.datetime(2018, 2, 3, 15, 0),
#  datetime.datetime(2018, 2, 3, 16, 0),
#  datetime.datetime(2018, 2, 3, 17, 0),
#  datetime.datetime(2018, 2, 3, 18, 0),
#  datetime.datetime(2018, 2, 3, 19, 0),
#  datetime.datetime(2018, 2, 3, 20, 0),
#  datetime.datetime(2018, 2, 3, 21, 0),
#  datetime.datetime(2018, 2, 3, 22, 0),
#  datetime.datetime(2018, 2, 3, 23, 0),
#  datetime.datetime(2018, 2, 4, 0, 0),
#  datetime.datetime(2018, 2, 4, 1, 0),
#  datetime.datetime(2018, 2, 4, 2, 0),
#  datetime.datetime(2018, 2, 4, 3, 0),
#  datetime.datetime(2018, 2, 4, 4, 0),
#  datetime.datetime(2018, 2, 4, 5, 0),
#  datetime.datetime(2018, 2, 4, 6, 0),
#  datetime.datetime(2018, 2, 4, 7, 0),
#  datetime.datetime(2018, 2, 4, 8, 0),
#  datetime.datetime(2018, 2, 4, 9, 0),
#  datetime.datetime(2018, 2, 4, 10, 0),
#  datetime.datetime(2018, 2, 4, 11, 0),
#  datetime.datetime(2018, 2, 4, 12, 0),
#  datetime.datetime(2018, 2, 4, 13, 0),
#  datetime.datetime(2018, 2, 4, 14, 0),
#  datetime.datetime(2018, 2, 4, 15, 0),
#  datetime.datetime(2018, 2, 4, 16, 0),
#  datetime.datetime(2018, 2, 4, 17, 0),
#  datetime.datetime(2018, 2, 4, 18, 0),
#  datetime.datetime(2018, 2, 4, 19, 0),
#  datetime.datetime(2018, 2, 4, 20, 0),
#  datetime.datetime(2018, 2, 4, 21, 0),
#  datetime.datetime(2018, 2, 4, 22, 0),
#  datetime.datetime(2018, 2, 4, 23, 0),
#  datetime.datetime(2018, 2, 5, 0, 0),
#  datetime.datetime(2018, 2, 5, 1, 0),
#  datetime.datetime(2018, 2, 5, 2, 0),
#  datetime.datetime(2018, 2, 5, 3, 0),
#  datetime.datetime(2018, 2, 5, 4, 0),
#  datetime.datetime(2018, 2, 5, 5, 0),
#  datetime.datetime(2018, 2, 5, 6, 0),
#  datetime.datetime(2018, 2, 5, 7, 0),
#  datetime.datetime(2018, 2, 5, 8, 0),
#  datetime.datetime(2018, 2, 5, 9, 0),
#  datetime.datetime(2018, 2, 5, 10, 0),
#  datetime.datetime(2018, 2, 5, 11, 0),
#  datetime.datetime(2018, 2, 5, 12, 0),
#  datetime.datetime(2018, 2, 5, 13, 0),
#  datetime.datetime(2018, 2, 5, 14, 0),
#  datetime.datetime(2018, 2, 5, 15, 0),
#  datetime.datetime(2018, 2, 5, 16, 0),
#  datetime.datetime(2018, 2, 5, 17, 0),
#  datetime.datetime(2018, 2, 5, 18, 0),
#  datetime.datetime(2018, 2, 5, 19, 0),
#  datetime.datetime(2018, 2, 5, 20, 0),
#  datetime.datetime(2018, 2, 5, 21, 0),
#  datetime.datetime(2018, 2, 5, 22, 0),
#  datetime.datetime(2018, 2, 5, 23, 0),
#  datetime.datetime(2018, 2, 6, 0, 0),
#  datetime.datetime(2018, 2, 6, 1, 0),
#  datetime.datetime(2018, 2, 6, 2, 0),
#  datetime.datetime(2018, 2, 6, 3, 0),
#  datetime.datetime(2018, 2, 6, 4, 0),
#  datetime.datetime(2018, 2, 6, 5, 0),
#  datetime.datetime(2018, 2, 6, 6, 0),
#  datetime.datetime(2018, 2, 6, 7, 0),
#  datetime.datetime(2018, 2, 6, 8, 0),
#  datetime.datetime(2018, 2, 6, 9, 0),
#  datetime.datetime(2018, 2, 6, 10, 0),
#  datetime.datetime(2018, 2, 6, 11, 0),
#  datetime.datetime(2018, 2, 6, 12, 0),
#  datetime.datetime(2018, 2, 6, 13, 0),
#  datetime.datetime(2018, 2, 6, 14, 0),
#  datetime.datetime(2018, 2, 6, 15, 0),
#  datetime.datetime(2018, 2, 6, 16, 0),
#  datetime.datetime(2018, 2, 6, 17, 0),
#  datetime.datetime(2018, 2, 6, 18, 0),
#  datetime.datetime(2018, 2, 6, 19, 0),
#  datetime.datetime(2018, 2, 6, 20, 0),
#  datetime.datetime(2018, 2, 6, 21, 0),
#  datetime.datetime(2018, 2, 6, 22, 0),
#  datetime.datetime(2018, 2, 6, 23, 0),
#  datetime.datetime(2018, 2, 7, 0, 0),
#  datetime.datetime(2018, 2, 7, 1, 0),
#  datetime.datetime(2018, 2, 7, 2, 0),
#  datetime.datetime(2018, 2, 7, 3, 0),
#  datetime.datetime(2018, 2, 7, 4, 0),
#  datetime.datetime(2018, 2, 7, 5, 0),
#  datetime.datetime(2018, 2, 7, 6, 0),
#  datetime.datetime(2018, 2, 7, 7, 0),
#  datetime.datetime(2018, 2, 7, 8, 0),
#  datetime.datetime(2018, 2, 7, 9, 0),
#  datetime.datetime(2018, 2, 7, 10, 0),
#  datetime.datetime(2018, 2, 7, 11, 0),
#  datetime.datetime(2018, 2, 7, 12, 0),
#  datetime.datetime(2018, 2, 7, 13, 0),
#  datetime.datetime(2018, 2, 7, 14, 0),
#  datetime.datetime(2018, 2, 7, 15, 0),
#  datetime.datetime(2018, 2, 7, 16, 0),
#  datetime.datetime(2018, 2, 7, 17, 0),
#  datetime.datetime(2018, 2, 7, 18, 0),
#  datetime.datetime(2018, 2, 7, 19, 0),
#  datetime.datetime(2018, 2, 7, 20, 0),
#  datetime.datetime(2018, 2, 7, 21, 0),
#  datetime.datetime(2018, 2, 7, 22, 0),
#  datetime.datetime(2018, 2, 7, 23, 0),
#  datetime.datetime(2018, 2, 8, 0, 0),
#  datetime.datetime(2018, 2, 8, 1, 0),
#  datetime.datetime(2018, 2, 8, 2, 0),
#  datetime.datetime(2018, 2, 8, 3, 0),
#  datetime.datetime(2018, 2, 8, 4, 0),
#  datetime.datetime(2018, 2, 8, 5, 0),
#  datetime.datetime(2018, 2, 8, 6, 0),
#  datetime.datetime(2018, 2, 8, 7, 0),
#  datetime.datetime(2018, 2, 8, 8, 0),
#  datetime.datetime(2018, 2, 8, 9, 0),
#  datetime.datetime(2018, 2, 8, 10, 0),
#  datetime.datetime(2018, 2, 8, 11, 0),
#  datetime.datetime(2018, 2, 8, 12, 0),
#  datetime.datetime(2018, 2, 8, 13, 0),
#  datetime.datetime(2018, 2, 8, 14, 0),
#  datetime.datetime(2018, 2, 8, 15, 0),
#  datetime.datetime(2018, 2, 8, 16, 0),
#  datetime.datetime(2018, 2, 8, 17, 0),
#  datetime.datetime(2018, 2, 8, 18, 0),
#  datetime.datetime(2018, 2, 8, 19, 0),
#  datetime.datetime(2018, 2, 8, 20, 0),
#  datetime.datetime(2018, 2, 8, 21, 0),
#  datetime.datetime(2018, 2, 8, 22, 0),
#  datetime.datetime(2018, 2, 8, 23, 0),
#  datetime.datetime(2018, 2, 9, 0, 0),
#  datetime.datetime(2018, 2, 9, 1, 0),
#  datetime.datetime(2018, 2, 9, 2, 0),
#  datetime.datetime(2018, 2, 9, 3, 0),
#  datetime.datetime(2018, 2, 9, 4, 0),
#  datetime.datetime(2018, 2, 9, 5, 0),
#  datetime.datetime(2018, 2, 9, 6, 0),
#  datetime.datetime(2018, 2, 9, 7, 0),
#  datetime.datetime(2018, 2, 9, 8, 0),
#  datetime.datetime(2018, 2, 9, 9, 0),
#  datetime.datetime(2018, 2, 9, 10, 0),
#  datetime.datetime(2018, 2, 9, 11, 0),
#  datetime.datetime(2018, 2, 9, 12, 0),
#  datetime.datetime(2018, 2, 9, 13, 0),
#  datetime.datetime(2018, 2, 9, 14, 0),
#  datetime.datetime(2018, 2, 9, 15, 0),
#  datetime.datetime(2018, 2, 9, 16, 0),
#  datetime.datetime(2018, 2, 9, 17, 0),
#  datetime.datetime(2018, 2, 9, 18, 0),
#  datetime.datetime(2018, 2, 9, 19, 0),
#  datetime.datetime(2018, 2, 9, 20, 0),
#  datetime.datetime(2018, 2, 9, 21, 0),
#  datetime.datetime(2018, 2, 9, 22, 0),
#  datetime.datetime(2018, 2, 9, 23, 0),
#  datetime.datetime(2018, 2, 10, 0, 0),
#  datetime.datetime(2018, 2, 10, 1, 0),
#  datetime.datetime(2018, 2, 10, 2, 0),
#  datetime.datetime(2018, 2, 10, 3, 0),
#  datetime.datetime(2018, 2, 10, 4, 0),
#  datetime.datetime(2018, 2, 10, 5, 0),
#  datetime.datetime(2018, 2, 10, 6, 0),
#  datetime.datetime(2018, 2, 10, 7, 0),
#  datetime.datetime(2018, 2, 10, 8, 0),
#  datetime.datetime(2018, 2, 10, 9, 0),
#  datetime.datetime(2018, 2, 10, 10, 0),
#  datetime.datetime(2018, 2, 10, 11, 0),
#  datetime.datetime(2018, 2, 10, 12, 0),
#  datetime.datetime(2018, 2, 10, 13, 0),
#  datetime.datetime(2018, 2, 10, 14, 0),
#  datetime.datetime(2018, 2, 10, 15, 0),
#  datetime.datetime(2018, 2, 10, 16, 0),
#  datetime.datetime(2018, 2, 10, 17, 0),
#  datetime.datetime(2018, 2, 10, 18, 0),
#  datetime.datetime(2018, 2, 10, 19, 0),
#  datetime.datetime(2018, 2, 10, 20, 0),
#  datetime.datetime(2018, 2, 10, 21, 0),
#  datetime.datetime(2018, 2, 10, 22, 0),
#  datetime.datetime(2018, 2, 10, 23, 0),
#  datetime.datetime(2018, 2, 11, 0, 0),
#  datetime.datetime(2018, 2, 11, 1, 0),
#  datetime.datetime(2018, 2, 11, 2, 0),
#  datetime.datetime(2018, 2, 11, 3, 0),
#  datetime.datetime(2018, 2, 11, 4, 0),
#  datetime.datetime(2018, 2, 11, 5, 0),
#  datetime.datetime(2018, 2, 11, 6, 0),
#  datetime.datetime(2018, 2, 11, 7, 0),
#  datetime.datetime(2018, 2, 11, 8, 0),
#  datetime.datetime(2018, 2, 11, 9, 0),
#  datetime.datetime(2018, 2, 11, 10, 0),
#  datetime.datetime(2018, 2, 11, 11, 0),
#  datetime.datetime(2018, 2, 11, 12, 0),
#  datetime.datetime(2018, 2, 11, 13, 0),
#  datetime.datetime(2018, 2, 11, 14, 0),
#  datetime.datetime(2018, 2, 11, 15, 0),
#  ...]

# %%
o.animation()
# Out:
# 17:10:47 INFO    opendrift.models.basemodel:3832: Time to make animation: 0:00:03.649604
